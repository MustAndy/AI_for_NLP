# %%
from gensim.models.word2vec import LineSentence
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# d:\anaconda3\envs\aicourse\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from gensim.models import Word2Vec

# %%
sentences = [["cat", "say", "meow"], ["dog", "say", "woof"]]
model = Word2Vec(sentences, min_count=1)

# %%
model.wv.vocab
# Out:
# {'cat': <gensim.models.keyedvectors.Vocab at 0x19883194438>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x19883194470>,
#  'meow': <gensim.models.keyedvectors.Vocab at 0x198831944a8>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x198831944e0>,
#  'woof': <gensim.models.keyedvectors.Vocab at 0x19883194518>}

# %%
model.most_similar('cat')
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('dog', 0.03251712769269943),
#  ('say', 0.005514681339263916),
#  ('woof', 0.0020492933690547943),
#  ('meow', -0.11644413322210312)]

# %%
model.wv['dog']
# Out:
# array([-0.00291042, -0.00025703,  0.00270824, -0.00185739,  0.00295315,
#         0.00187376,  0.00395725,  0.00142758, -0.00285923, -0.00339562,
#        -0.00295282,  0.00061519, -0.00477827,  0.00170297,  0.00408047,
#         0.00077571, -0.00490463, -0.00394283, -0.00229102, -0.00078137,
#        -0.00283009, -0.00371713,  0.00154284,  0.00450631,  0.00187989,
#        -0.00066266, -0.00412124,  0.00108158, -0.0008055 , -0.00468433,
#        -0.0046149 ,  0.00267089,  0.00237368, -0.00021969,  0.00160353,
#         0.0038303 , -0.00481247,  0.00431197, -0.00462471,  0.00045866,
#        -0.00462051,  0.00056329,  0.00305545,  0.00151274,  0.00336323,
#         0.00391891,  0.00095492, -0.00019918,  0.00332058, -0.00154678,
#        -0.00011041,  0.0008197 , -0.00311257,  0.00377885, -0.00258659,
#        -0.00484798,  0.00134681,  0.00155908,  0.000516  ,  0.00095606,
#         0.00221612,  0.00288947,  0.00207716,  0.00435599,  0.00346709,
# ...

# %%
database = 'D://senior/aiCourse/AI_for_NLP/sqlResult_1558435.csv'
import pandas as pd
content = pd.read_csv(database, encoding='gb18030')
samples = content['content']

# %%
import jieba

# %%
def cut(string): return ' '.join(jieba.cut(string))

# %%
samples
# Out:
# 0        此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1        骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2        此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3          这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4        （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
# 5        　　受到A股被纳入MSCI指数的利好消息刺激，A股市场从周三开始再度上演龙马行情，周四上午金...
# 6        虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是...
# 7        　　沙漠雄鹰：震荡有利消化套牢筹码\r\n　　周四开盘上证50在银行券商大蓝筹带动下一度涨近...
# 8        （原标题：武汉警方一下子抓了808人，还都是俊男靓女！原来他们每天偷偷摸摸干这事！）\r\n...
# 9        　　6月21日，A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22...
# 10       　　证券时报网（www.stcn.com）06月23日讯\r\n　　据上证报道，6月初以来，...
# 11       ?\r\n　　巨丰早评：市场将再次探底\r\n　　【巨丰观点】\r\n　　周四大盘冲高回落，...
# 12       中新网6月19日电 据外媒报道，美国底特律一名男子1976年因为一根头发被定谋杀罪，监禁41...
# 13       　　曹先生：风格转换前的阵痛\r\n　　今日早盘两地低开，之后一度震荡走高，领涨的仍然是上证...
# 14       6月21日，MSCI在官网发布公告称，从明年6月起将中国A股纳入MSCI新兴市场指数和MSC...
# 15       　　中国证券网讯（记者 费天元）沪深两市周五临近午盘出现快速跳水，沪指连续跌穿5日、10日及...
# ...

# %% [markdown]
# with open('D://senior/aiCourse/AI_for_NLP/mini_samples.txt', 'w',encoding='gb18030') as f:
#     for s in samples:
#         f.write(cut(str(s)) + '\n')

# %% [markdown]
# f1 = open('D://senior/aiCourse/AI_for_NLP/mini_samples.txt', 'r',encoding='gb18030')
#
# f2 = open('D://senior/aiCourse/AI_for_NLP/wiki_word_cut_output.txt', 'r',encoding='gb18030')

# %% [markdown]
# with open('D://senior/aiCourse/AI_for_NLP/wiki_news_cutting.txt','w',encoding='gb18030') as inputfile:
#     for line in f1:
#         inputfile.write(line)
#     for line1 in f2:
#         inputfile.write(line1)

# %%
sentences = LineSentence(open('D://senior/aiCourse/AI_for_NLP/mini_samples.txt',encoding='gb18030'))

# %%
model = Word2Vec(sentences, min_count=1)

# %%
model.wv['小米']
# Out:
# array([ 2.43824851e-02,  1.02894902e-02, -5.32995798e-02, -2.52373214e-03,
#        -2.92671821e-03,  2.85192281e-02, -1.18015241e-02, -2.47134990e-03,
#        -6.81273863e-02,  1.87935382e-02,  1.15440330e-02,  2.47160532e-03,
#         1.18308831e-02,  3.78909446e-02,  1.98541228e-02,  3.97885405e-03,
#         6.02641068e-02,  2.23905835e-02,  1.11081777e-02, -1.03858495e-02,
#         2.79745497e-02,  1.66229066e-02,  2.68453695e-02, -1.42993005e-02,
#         2.15604790e-02, -3.66114639e-02,  4.66803014e-02,  1.93315116e-03,
#        -9.54185054e-03, -1.16965817e-02, -2.09978614e-02, -4.55032103e-02,
#         2.31528450e-02,  1.83721706e-02, -2.00863201e-02, -1.38899470e-02,
#        -5.17083518e-02,  4.50511947e-02, -5.02223298e-02,  3.09450109e-03,
#         1.38659989e-02, -7.67012170e-05, -4.64069732e-02,  3.08113918e-02,
#        -1.91304181e-02, -2.05749137e-04, -2.66729631e-02, -5.26166288e-04,
# ...

# %%
model.most_similar('小米')
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('类', 0.994957447052002),
#  ('不会', 0.9948529005050659),
#  ('7', 0.9947829842567444),
#  ('视网', 0.9947828054428101),
#  ('发现', 0.9947637319564819),
#  ('短期', 0.9947600364685059),
#  ('+', 0.9947486519813538),
#  ('提升', 0.9947397708892822),
#  ('当时', 0.9947350025177002),
#  ('展示', 0.9947202205657959)]

# %%
model.wv.vocab
# Out:
# {'此外': <gensim.models.keyedvectors.Vocab at 0x1989820deb8>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x19897e84cf8>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x19897e849e8>,
#  '本周': <gensim.models.keyedvectors.Vocab at 0x19897e84a58>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x19897e84f28>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x19897e84f98>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x19897e84320>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x19897e845f8>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x19897e96eb8>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x19897e965c0>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x19897e965f8>,
#  '除': <gensim.models.keyedvectors.Vocab at 0x19897e96080>,
#  '小米': <gensim.models.keyedvectors.Vocab at 0x19897e960f0>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x19897e96160>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x19897e961d0>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x19897e96240>,
# ...

# %% [markdown]
# ## 现在是 mini 测试集，如果大家把维基百科+新闻语料库的所有信息全部加上，那么效果肯定会不错的

# %% [markdown]
# import re
# symbol='[^（|^）|^《|^》|^、|^“|^”|^「|^」|^：|^?|^\(|^\)|^·|^……|^；|^，|^\-|^,|^。|^:|^-|^.|^/]'
# symbol='[^(（|）|《|》|“|”|「|」|，|。|、|\-|：|·|；|?|,|.|:|"|\'|\')]'
# #print(symbol)
# def token(string):
#     return ''.join(re.findall(symbol,string))
# content = list()
# with open("D://senior/aiCourse/AI_for_NLP/output_zhwiki.txt",encoding='gb18030') as inputFile:
#     for line in inputFile:
#         content.append(token(str(line)))
#
# """with open('wiki_word_cut_output.txt', 'w',encoding='gb18030') as f:
#     f.write(cut(text) + '\n')"""

# %% [markdown]
# with open('D://senior/aiCourse/AI_for_NLP/wiki_word_cut_output.txt', 'w',encoding='gb18030') as f:
#     for cont in content:
#         f.write(cut(cont)+'\n')

# %%
sentences_wiki = LineSentence(open('./wiki_word_cut_output.txt',encoding='gb18030'))

# %%
model_wiki = Word2Vec(sentences_wiki, min_count=1, workers=8)

# %%
model_wiki.wv['数学']
# Out:
# array([-3.0885653e+00, -1.8269283e-01, -1.5537006e+00,  6.9298333e-01,
#         1.7376687e-01,  2.6447877e-01,  3.5894725e-01, -4.1696829e-01,
#         1.0150263e+00,  7.4280970e-02,  2.2938488e-01,  2.3033876e+00,
#        -3.3072636e+00,  8.6728239e-01,  6.7922336e-01, -3.5787578e+00,
#         1.5994387e+00, -2.2107170e+00, -1.2253116e+00, -2.8080683e+00,
#        -1.6978714e+00, -2.1287398e+00,  1.8574107e+00, -9.3597986e-02,
#        -7.6136106e-01, -5.2528236e-02, -9.6218145e-01,  3.8828725e-01,
#        -3.1233129e-01, -1.2571319e+00,  3.6064255e+00,  1.4689661e+00,
#         1.3079387e+00, -1.4083418e+00, -2.2441742e+00,  3.4256154e-01,
#         5.0745302e-01,  2.4612470e+00,  4.9507859e-01,  6.9859400e-02,
#        -3.4962437e+00, -3.0468592e-01,  1.3595114e+00,  2.4996781e+00,
#        -7.1102864e-01,  4.3049073e+00, -3.6559174e+00, -8.8668323e-01,
#         2.0907116e+00,  2.1288273e+00,  2.1758530e+00,  1.5339549e+00,
# ...

# %%
model_wiki.most_similar('数学',topn=20)
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('物理', 0.8458156585693359),
#  ('计算机科学', 0.8412859439849854),
#  ('物理学', 0.8242582082748413),
#  ('统计学', 0.8203920125961304),
#  ('语言学', 0.7993844747543335),
#  ('哲学', 0.7975299954414368),
#  ('数论', 0.7832486629486084),
#  ('历史学', 0.7826335430145264),
#  ('逻辑学', 0.7826277613639832),
#  ('天文学', 0.7810382843017578),
#  ('社会学', 0.7804080843925476),
#  ('理论', 0.7763649225234985),
#  ('微积分', 0.7711677551269531),
#  ('几何学', 0.7673635482788086),
#  ('力学', 0.7666369676589966),
#  ('政治学', 0.7654010057449341),
#  ('伦理学', 0.7647632360458374),
#  ('数学分析', 0.7605448365211487),
#  ('心理学', 0.7569896578788757),
#  ('逻辑', 0.7558256387710571)]

# %% [markdown]
# ## Name Entity Recoginition

# %% [markdown]
# 区分出来什么是人名（person）， 组织机构名(organization), 地点(location)

# %% [markdown]
# ### 1. jieba

# %%
from jieba import posseg

# %% [markdown]
# posseg ==> Part of Speech Segment

# %%
text = """新华社华盛顿4月26日电 美国总统特朗普26日表示，美国将撤销在《武器贸易条约》上的签字。特朗普当天在美国印第安纳州首府印第安纳波利斯举行的美国全国步枪协会年会上说，《武器贸易条约》是一个“严重误导的条约”，美国将撤销在该条约上的签字，联合国将很快收到美国正式拒绝该条约的通知。"""

# %%
for w in posseg.cut(text):
    print(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4513f62976cb> in <module>
# ----> 1 for w in posseg.cut(text):
#       2     print(w)
#
# NameError: name 'posseg' is not defined

# %% [markdown]
# ## 哈工大的 LTP

# %%
## https://pyltp.readthedocs.io/zh_CN/latest/api.html#id13

# %% [markdown]
# # Dependency Parsing 依存分析

# %%
from pyltp import SentenceSplitter
sents = SentenceSplitter.split('元芳你怎么看？我就趴窗口上看呗！')  # 分句
print ('\n'.join(sents))
# Out:
# 元芳你怎么看？
# 我就趴窗口上看呗！

# %%
import os
LTP_DATA_DIR = 'D://senior/aiCourse/dataSource/ltp_data_v3.4.0/'  # ltp模型目录的路径
cws_model_path = os.path.join(LTP_DATA_DIR, 'cws.model')
pos_model_path = os.path.join(LTP_DATA_DIR, 'pos.model')
ner_model_path = os.path.join(LTP_DATA_DIR, 'ner.model')
par_model_path = os.path.join(LTP_DATA_DIR, 'parser.model')
srl_model_path = os.path.join(LTP_DATA_DIR, 'pisrl_win.model')

# %%
from pyltp import Segmentor
segmentor = Segmentor()  # 初始化实例
segmentor.load(cws_model_path)  # 加载模型
words = segmentor.segment(text)  # 分词
print ('\t'.join(words))
segmentor.release()  # 释放模型
# Out:
# 新华社	华盛顿	4月	26日	电	美国	总统	特朗普	26日	表示	，	美国	将	撤销	在	《	武器	贸易	条约	》	上	的	签字	。特朗普	当天	在	美国	印第安纳州	首府	印第安纳波利斯	举行	的	美国	全国	步枪	协会	年会	上	说	，	《	武器	贸易	条约	》	是	一个	“	严重	误导	的	条约	”	，	美国	将	撤销	在	该	条约	上	的	签字	，	联合国	将	很快	收到	美国	正式	拒绝	该	条约	的	通知	。

# %%
from pyltp import Postagger
postagger = Postagger() # 初始化实例
postagger.load(pos_model_path)  # 加载模型

postags = postagger.postag(words)  # 词性标注

print ('\t'.join(postags))
postagger.release()  # 释放模型
# Out:
# ni	ns	nt	nt	n	ns	n	nh	nt	v	wp	ns	d	v	p	wp	n	v	n	wp	nd	u	v	wp	nt	p	ns	ns	n	ns	v	u	ns	n	n	n	n	nd	v	wp	wp	n	v	n	wp	v	m	wp	a	v	u	n	wp	wp	ns	d	v	p	r	n	nd	u	v	wp	ni	d	d	v	ns	a	v	r	n	u	n	wp

# %%
from pyltp import NamedEntityRecognizer
recognizer = NamedEntityRecognizer() # 初始化实例
recognizer.load(ner_model_path)  # 加载模型


netags = recognizer.recognize(words, postags)  # 命名实体识别

print ('\t'.join(netags))
recognizer.release()  # 释放模型
# Out:
# S-Ni	S-Ns	O	O	O	S-Ns	O	S-Nh	O	O	O	S-Ns	O	O	O	O	O	O	O	O	O	O	O	O	O	O	B-Ns	E-Ns	O	S-Ns	O	O	B-Ni	I-Ni	I-Ni	E-Ni	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	S-Ns	O	O	O	O	O	O	O	O	O	S-Ni	O	O	O	S-Ns	O	O	O	O	O	O	O

# %%
from pyltp import Parser
parser = Parser() # 初始化实例
parser.load(par_model_path)  # 加载模型


arcs = parser.parse(words, postags)  # 句法分析

print ("\t".join("%d:%s" % (arc.head, arc.relation) for arc in arcs))
parser.release()  # 释放模型
# Out:
# 10:SBV	10:SBV	4:ATT	10:ADV	10:SBV	7:ATT	8:ATT	10:SBV	10:ADV	0:HED	10:WP	14:SBV	14:ADV	10:VOB	23:ATT	19:WP	18:ATT	19:ATT	21:ATT	19:WP	15:POB	15:RAD	14:VOB	14:WP	31:ADV	31:ADV	28:ATT	29:ATT	30:ATT	26:POB	37:ATT	31:RAD	36:ATT	36:ATT	36:ATT	37:ATT	38:ATT	39:ADV	14:COO	39:WP	44:WP	43:ATT	44:ATT	46:SBV	44:WP	39:VOB	52:ATT	52:WP	50:ADV	52:ATT	50:RAD	46:VOB	52:WP	46:WP	57:SBV	57:ADV	46:COO	63:ATT	60:ATT	61:ATT	58:POB	58:RAD	57:VOB	57:WP	68:SBV	68:ADV	68:ADV	57:COO	71:SBV	71:ADV	75:ATT	73:ATT	71:VOB	71:RAD	68:VOB	10:WP

# %%
from pyltp import SementicRoleLabeller
labeller = SementicRoleLabeller() # 初始化实例
labeller.load(srl_model_path)  # 加载模型


# arcs 使用依存句法分析的结果
roles = labeller.label(words, postags, arcs)  # 语义角色标注

# 打印结果
for role in roles:
    print (role.index, "".join(
        ["%s:(%d,%d)" % (arg.name, arg.range.start, arg.range.end) for arg in role.arguments]))
labeller.release()  # 释放模型
# Out:
# 9 TMP:(8,8)A1:(11,74)
# 13 A0:(11,11)ADV:(12,12)A1:(23,23)A1:(24,36)
# 30 TMP:(24,24)LOC:(25,29)
# 38 A0:(11,11)A1:(40,74)
# 45 A0:(40,44)A1:(46,52)
# 49 ADV:(48,48)
# 56 A0:(54,54)ADV:(55,55)A1:(57,62)
# 67 A0:(64,64)ADV:(65,65)ADV:(66,66)A1:(68,74)
# 70 A0:(68,68)ADV:(69,69)A1:(71,72)

# %% [markdown]
# 新华社	华盛顿	4月	26日	电	美国	总统	特朗普	26日	表示	，	美国	将	撤销	在	《	武器	贸易	条约	》	上	的	签字	。特朗普	当天	在	美国	印第安纳州	首府	印第安纳波利斯	举行	的	美国	全国	步枪	协会	年会	上	说	，	《	武器	贸易	条约	》	是	一个	“	严重	误导	的	条约	”	，	美国	将	撤销	在	该	条约	上	的	签字	，	联合国	将	很快	收到	美国	正式	拒绝	该	条约	的	通知	。

# %%
length = len(words)
print(len(words),len(postags),len(netags))
for i in range(length):
    print('{} {} {} '.format(words[i],postags[i],netags[i]))
# Out:
# 76 76 76
# 新华社 ni S-Ni
# 华盛顿 ns S-Ns
# 4月 nt O
# 26日 nt O
# 电 n O
# 美国 ns S-Ns
# 总统 n O
# 特朗普 nh S-Nh
# 26日 nt O
# 表示 v O
# ， wp O
# 美国 ns S-Ns
# 将 d O
# 撤销 v O
# 在 p O
# 《 wp O
# 武器 n O
# 贸易 v O
# 条约 n O
# 》 wp O
# 上 nd O
# 的 u O
# 签字 v O
# 。特朗普 wp O
# 当天 nt O
# 在 p O
# 美国 ns B-Ns
# 印第安纳州 ns E-Ns
# 首府 n O
# 印第安纳波利斯 ns S-Ns
# 举行 v O
# 的 u O
# 美国 ns B-Ni
# 全国 n I-Ni
# 步枪 n I-Ni
# 协会 n E-Ni
# 年会 n O
# 上 nd O
# 说 v O
# ， wp O
# 《 wp O
# 武器 n O
# 贸易 v O
# 条约 n O
# 》 wp O
# 是 v O
# 一个 m O
# “ wp O
# 严重 a O
# 误导 v O
# 的 u O
# 条约 n O
# ” wp O
# ， wp O
# 美国 ns S-Ns
# 将 d O
# 撤销 v O
# 在 p O
# 该 r O
# 条约 n O
# 上 nd O
# 的 u O
# 签字 v O
# ， wp O
# 联合国 ni S-Ni
# 将 d O
# 很快 d O
# 收到 v O
# 美国 ns S-Ns
# 正式 a O
# 拒绝 v O
# 该 r O
# 条约 n O
# 的 u O
# 通知 n O
# 。 wp O
