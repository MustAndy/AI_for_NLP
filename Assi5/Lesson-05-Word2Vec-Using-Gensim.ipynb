# %%
from gensim.models.word2vec import LineSentence
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# d:\anaconda3\envs\aicourse\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from gensim.models import Word2Vec

# %%
sentences = [["cat", "say", "meow"], ["dog", "say", "woof"]]
model = Word2Vec(sentences, min_count=1)

# %%
model.wv.vocab
# Out:
# {'cat': <gensim.models.keyedvectors.Vocab at 0x259abb7b128>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x259abb7b160>,
#  'meow': <gensim.models.keyedvectors.Vocab at 0x259abb7b198>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x259abb7b1d0>,
#  'woof': <gensim.models.keyedvectors.Vocab at 0x259abb7b208>}

# %%
model.most_similar('cat')
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('dog', 0.11971732974052429),
#  ('say', 0.06519065052270889),
#  ('woof', 0.021819312125444412),
#  ('meow', -0.04818447306752205)]

# %%
model.wv['dog']
# Out:
# array([ 6.2594900e-04, -3.6220830e-03,  3.5789963e-03, -2.3246440e-04,
#         5.1735563e-04, -1.3764905e-03,  8.0236234e-04, -4.2941058e-03,
#        -7.9403166e-04, -2.8402151e-03, -2.5206397e-03,  4.4551562e-03,
#         3.7617239e-03, -1.2040486e-04, -3.5362777e-03,  3.6053073e-03,
#         2.9744662e-03, -3.0673766e-03, -2.6380253e-04, -2.7003565e-03,
#         2.9417593e-03,  2.0004928e-03,  1.3684916e-03, -5.4507464e-04,
#         2.6037239e-03,  1.5600286e-03, -1.1243988e-03,  3.7005844e-03,
#        -4.0912139e-03,  4.3782415e-03,  3.1518713e-03, -3.9024686e-03,
#        -4.5033526e-03, -3.8732346e-03,  2.8633040e-03,  4.4266359e-05,
#         2.3112216e-03, -4.6650837e-03, -4.4927015e-03,  3.9180191e-04,
#         2.3024052e-03,  8.0807676e-04, -3.9937655e-03, -2.2034138e-04,
#        -1.0840076e-03, -1.2023788e-03,  1.4981471e-03,  2.9035604e-03,
#         2.1010649e-03,  1.2803320e-03,  2.9739842e-03,  3.1103094e-03,
#        -3.7086783e-03,  7.1646849e-04, -3.7541459e-03, -2.9820455e-03,
#         1.4574711e-04,  3.2978731e-03, -2.9544921e-03, -2.8078670e-03,
#        -4.5469850e-03, -1.6543046e-03, -4.9453042e-03, -1.5361650e-03,
#        -8.6629319e-05,  4.2818530e-04,  4.4279625e-03,  1.0533525e-04,
#         4.0447623e-03, -4.3518175e-03,  2.4012213e-03, -1.1867619e-03,
#        -3.7680762e-03, -7.7654293e-04,  4.2686320e-04, -2.3989791e-04,
#        -4.6228557e-03,  1.0340038e-03,  2.9319099e-03,  1.0846147e-03,
#         2.0724956e-03, -4.6744701e-03, -8.9904247e-04,  1.0317712e-03,
#        -1.1224319e-03, -2.8954111e-03, -3.2801714e-03, -4.1112956e-03,
#         4.7010584e-03,  4.4689318e-03, -1.8378403e-03,  3.1342434e-03,
#         2.7962378e-03, -2.9571843e-03, -2.1587629e-03, -1.3731330e-04,
#        -2.8427425e-03,  3.8945456e-03,  4.8571248e-03, -1.5021686e-03],
#       dtype=float32)

# %%
database = './sqlResult_1558435.csv'
import pandas as pd
content = pd.read_csv(database, encoding='gb18030')
samples = content['content'][:100].tolist()

# %%
import jieba

# %%
def cut(string): return ' '.join(jieba.cut(string))

# %%
cut('这是一个测试')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\dell\AppData\Local\Temp\jieba.cache
# Loading model cost 0.742 seconds.
# Prefix dict has been built succesfully.
# '这是 一个 测试'

# %%
with open('mini_samples.txt', 'w',encoding='gb18030') as f:
    for s in samples: 
        f.write(cut(s) + '\n')

# %%
sentences = LineSentence(open('mini_samples.txt',encoding='gb18030'))

# %%
model = Word2Vec(sentences, min_count=1)

# %%
model.wv['小米']
# Out:
# array([-0.03374504,  0.00715528,  0.02675863,  0.02025711, -0.0151746 ,
#         0.0127579 ,  0.03633015, -0.02091399,  0.01044633, -0.03114718,
#         0.02185283, -0.01906482,  0.019124  ,  0.03568058,  0.00072191,
#         0.00970583, -0.01655277, -0.04696377, -0.00148032, -0.02743685,
#        -0.01283823, -0.02089681, -0.00018286, -0.00982931, -0.00656696,
#         0.00556639, -0.00934789,  0.00326882,  0.01641832, -0.02552284,
#        -0.02841939,  0.01401644,  0.00012188, -0.00726213, -0.00750393,
#         0.02056472, -0.01611481, -0.01872413,  0.0251881 ,  0.01015395,
#        -0.00313151, -0.04774113, -0.01649023, -0.0068597 ,  0.01986416,
#         0.01315898,  0.00116028, -0.06534462,  0.01135989, -0.01535294,
#        -0.00783964,  0.0138588 ,  0.00989761, -0.03281833,  0.03115591,
#         0.01215531, -0.00269346,  0.02031112, -0.00822018, -0.00916899,
#        -0.0201094 ,  0.01099855,  0.03687671,  0.01496009,  0.00788034,
#        -0.03440961, -0.02088401,  0.04060024, -0.02498713, -0.06366289,
#         0.01590697,  0.00369157,  0.01296827, -0.0022858 ,  0.01818592,
#        -0.03533836, -0.03596356, -0.01343681, -0.01667939, -0.01851436,
#        -0.00219383,  0.02288569,  0.00266244,  0.04763529, -0.01668707,
#        -0.02904126, -0.01669133, -0.00345887, -0.00540219, -0.00329927,
#        -0.06342112,  0.01083002, -0.02530299, -0.00381869, -0.04397242,
#         0.03995099,  0.00356333,  0.00577884, -0.00368479, -0.00138289],
#       dtype=float32)

# %%
model.most_similar('小米')
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('新能源', 0.9927558302879333),
#  ('改革', 0.9921313524246216),
#  ('转型', 0.9921121001243591),
#  ('数字', 0.9920080304145813),
#  ('至少', 0.9920065402984619),
#  ('公布', 0.9919847249984741),
#  ('共同', 0.991950511932373),
#  ('只有', 0.9919447302818298),
#  ('服务', 0.9919086694717407),
#  ('来', 0.9919086694717407)]

# %%
model.wv.vocab
# Out:
# {'此外': <gensim.models.keyedvectors.Vocab at 0x259c0048390>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x259c0048208>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x259c0048240>,
#  '本周': <gensim.models.keyedvectors.Vocab at 0x259c00484a8>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x259c00484e0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x259c0048518>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x259c0048550>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x259c0048588>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x259c00485c0>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x259c00485f8>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x259c0048630>,
#  '除': <gensim.models.keyedvectors.Vocab at 0x259c0048668>,
#  '小米': <gensim.models.keyedvectors.Vocab at 0x259c00486a0>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x259c00486d8>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x259c0048710>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x259c0048748>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x259c0048780>,
#  '机型': <gensim.models.keyedvectors.Vocab at 0x259c00487b8>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x259c00487f0>,
#  '其余': <gensim.models.keyedvectors.Vocab at 0x259c0048828>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x259c0048860>,
#  '暂停': <gensim.models.keyedvectors.Vocab at 0x259c0048898>,
#  '更新': <gensim.models.keyedvectors.Vocab at 0x259c00488d0>,
#  '发布': <gensim.models.keyedvectors.Vocab at 0x259c0048908>,
#  '含': <gensim.models.keyedvectors.Vocab at 0x259c0048940>,
#  '开发': <gensim.models.keyedvectors.Vocab at 0x259c0048978>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x259c00489b0>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x259c00489e8>,
#  '体验版': <gensim.models.keyedvectors.Vocab at 0x259c0048a20>,
#  '内测': <gensim.models.keyedvectors.Vocab at 0x259c0048a58>,
#  '稳定版': <gensim.models.keyedvectors.Vocab at 0x259c0048a90>,
#  '暂不受': <gensim.models.keyedvectors.Vocab at 0x259c0048ac8>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x259c0048b00>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x259c0048b38>,
#  '确保': <gensim.models.keyedvectors.Vocab at 0x259c0048b70>,
#  '工程师': <gensim.models.keyedvectors.Vocab at 0x259c0048ba8>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x259c0048be0>,
#  '集中': <gensim.models.keyedvectors.Vocab at 0x259c0048c18>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x259c0048c50>,
#  '精力': <gensim.models.keyedvectors.Vocab at 0x259c0048c88>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x259c0048cc0>,
#  '系统优化': <gensim.models.keyedvectors.Vocab at 0x259c0048cf8>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x259c0048d30>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x259c0048d68>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x259c0048da0>,
#  '猜测': <gensim.models.keyedvectors.Vocab at 0x259c0048dd8>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x259c0048e10>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x259c0048e48>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x259c0048e80>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x259c0048eb8>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x259c0048ef0>,
#  '用到': <gensim.models.keyedvectors.Vocab at 0x259c0048f28>,
#  'MIUI': <gensim.models.keyedvectors.Vocab at 0x259c0048f60>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x259c0048f98>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x259c0048fd0>,
#  '研发': <gensim.models.keyedvectors.Vocab at 0x259c004e048>,
#  '之中': <gensim.models.keyedvectors.Vocab at 0x259c004e080>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x259c004e0b8>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x259c004e0f0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x259c004e128>,
#  '距今已有': <gensim.models.keyedvectors.Vocab at 0x259c004e160>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x259c004e198>,
#  '有余': <gensim.models.keyedvectors.Vocab at 0x259c004e1d0>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x259c004e208>,
#  '更新换代': <gensim.models.keyedvectors.Vocab at 0x259c004e240>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x259c004e278>,
#  '当然': <gensim.models.keyedvectors.Vocab at 0x259c004e2b0>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x259c004e2e8>,
#  '确切': <gensim.models.keyedvectors.Vocab at 0x259c004e320>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x259c004e358>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x259c004e390>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x259c004e3c8>,
#  '等待': <gensim.models.keyedvectors.Vocab at 0x259c004e400>,
#  '官方消息': <gensim.models.keyedvectors.Vocab at 0x259c004e438>,
#  '骁龙': <gensim.models.keyedvectors.Vocab at 0x259c004e470>,
#  '835': <gensim.models.keyedvectors.Vocab at 0x259c004e4a8>,
#  '作为': <gensim.models.keyedvectors.Vocab at 0x259c004e4e0>,
#  '唯一': <gensim.models.keyedvectors.Vocab at 0x259c004e518>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x259c004e550>,
#  'Windows': <gensim.models.keyedvectors.Vocab at 0x259c004e588>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x259c004e5c0>,
#  '桌面': <gensim.models.keyedvectors.Vocab at 0x259c004e5f8>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x259c004e630>,
#  '认证': <gensim.models.keyedvectors.Vocab at 0x259c004e668>,
#  'ARM': <gensim.models.keyedvectors.Vocab at 0x259c004e6a0>,
#  '处理器': <gensim.models.keyedvectors.Vocab at 0x259c004e6d8>,
#  '高通': <gensim.models.keyedvectors.Vocab at 0x259c004e710>,
#  '强调': <gensim.models.keyedvectors.Vocab at 0x259c004e748>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x259c004e780>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x259c004e7b8>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x259c004e7f0>,
#  '考虑': <gensim.models.keyedvectors.Vocab at 0x259c004e828>,
#  '性能': <gensim.models.keyedvectors.Vocab at 0x259c004e860>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x259c004e898>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x259c004e8d0>,
#  '屏蔽掉': <gensim.models.keyedvectors.Vocab at 0x259c004e908>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x259c004e940>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x259c004e978>,
#  '相反': <gensim.models.keyedvectors.Vocab at 0x259c004e9b0>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x259c004e9e8>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x259c004ea20>,
#  '联手': <gensim.models.keyedvectors.Vocab at 0x259c004ea58>,
#  '微软': <gensim.models.keyedvectors.Vocab at 0x259c004ea90>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x259c004eac8>,
#  '一种': <gensim.models.keyedvectors.Vocab at 0x259c004eb00>,
#  '适合': <gensim.models.keyedvectors.Vocab at 0x259c004eb38>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x259c004eb70>,
#  '兼顾': <gensim.models.keyedvectors.Vocab at 0x259c004eba8>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x259c004ebe0>,
#  '功耗': <gensim.models.keyedvectors.Vocab at 0x259c004ec18>,
#  '完美': <gensim.models.keyedvectors.Vocab at 0x259c004ec50>,
#  '方案': <gensim.models.keyedvectors.Vocab at 0x259c004ec88>,
#  '报道': <gensim.models.keyedvectors.Vocab at 0x259c004ecc0>,
#  '称': <gensim.models.keyedvectors.Vocab at 0x259c004ecf8>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x259c004ed30>,
#  '拿到': <gensim.models.keyedvectors.Vocab at 0x259c004ed68>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x259c004eda0>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x259c004edd8>,
#  '源码': <gensim.models.keyedvectors.Vocab at 0x259c004ee10>,
#  '以便': <gensim.models.keyedvectors.Vocab at 0x259c004ee48>,
#  '更好': <gensim.models.keyedvectors.Vocab at 0x259c004ee80>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x259c004eeb8>,
#  '理解': <gensim.models.keyedvectors.Vocab at 0x259c004eef0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x259c004ef28>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x259c004ef60>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x259c004ef98>,
#  '架构': <gensim.models.keyedvectors.Vocab at 0x259c004efd0>,
#  '资料': <gensim.models.keyedvectors.Vocab at 0x259c0050048>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x259c0050080>,
#  '一款': <gensim.models.keyedvectors.Vocab at 0x259c00500b8>,
#  '集成': <gensim.models.keyedvectors.Vocab at 0x259c00500f0>,
#  'CPU': <gensim.models.keyedvectors.Vocab at 0x259c0050128>,
#  'GPU': <gensim.models.keyedvectors.Vocab at 0x259c0050160>,
#  '基带': <gensim.models.keyedvectors.Vocab at 0x259c0050198>,
#  '蓝牙': <gensim.models.keyedvectors.Vocab at 0x259c00501d0>,
#  'Wi': <gensim.models.keyedvectors.Vocab at 0x259c0050208>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x259c0050240>,
#  'Fi': <gensim.models.keyedvectors.Vocab at 0x259c0050278>,
#  'SoC': <gensim.models.keyedvectors.Vocab at 0x259c00502b0>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x259c00502e8>,
#  '传统': <gensim.models.keyedvectors.Vocab at 0x259c0050320>,
#  'Wintel': <gensim.models.keyedvectors.Vocab at 0x259c0050358>,
#  '节省': <gensim.models.keyedvectors.Vocab at 0x259c0050390>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x259c00503c8>,
#  '30%': <gensim.models.keyedvectors.Vocab at 0x259c0050400>,
#  'PCB': <gensim.models.keyedvectors.Vocab at 0x259c0050438>,
#  '空间': <gensim.models.keyedvectors.Vocab at 0x259c0050470>,
#  '按计划': <gensim.models.keyedvectors.Vocab at 0x259c00504a8>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x259c00504e0>,
#  'Q4': <gensim.models.keyedvectors.Vocab at 0x259c0050518>,
#  '华硕': <gensim.models.keyedvectors.Vocab at 0x259c0050550>,
#  '惠普': <gensim.models.keyedvectors.Vocab at 0x259c0050588>,
#  '联想': <gensim.models.keyedvectors.Vocab at 0x259c00505c0>,
#  '首发': <gensim.models.keyedvectors.Vocab at 0x259c00505f8>,
#  'Win10': <gensim.models.keyedvectors.Vocab at 0x259c0050630>,
#  '电脑': <gensim.models.keyedvectors.Vocab at 0x259c0050668>,
#  '预计': <gensim.models.keyedvectors.Vocab at 0x259c00506a0>,
#  '均': <gensim.models.keyedvectors.Vocab at 0x259c00506d8>,
#  '二合一': <gensim.models.keyedvectors.Vocab at 0x259c0050710>,
#  '形态': <gensim.models.keyedvectors.Vocab at 0x259c0050748>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x259c0050780>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x259c00507b8>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x259c00507f0>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x259c0050828>,
#  '未来': <gensim.models.keyedvectors.Vocab at 0x259c0050860>,
#  '也许': <gensim.models.keyedvectors.Vocab at 0x259c0050898>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x259c00508d0>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x259c0050908>,
#  '见到': <gensim.models.keyedvectors.Vocab at 0x259c0050940>,
#  '三星': <gensim.models.keyedvectors.Vocab at 0x259c0050978>,
#  'Exynos': <gensim.models.keyedvectors.Vocab at 0x259c00509b0>,
#  '联发科': <gensim.models.keyedvectors.Vocab at 0x259c00509e8>,
#  '华为': <gensim.models.keyedvectors.Vocab at 0x259c0050a20>,
#  '麒麟': <gensim.models.keyedvectors.Vocab at 0x259c0050a58>,
#  '澎湃': <gensim.models.keyedvectors.Vocab at 0x259c0050a90>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x259c0050ac8>,
#  '此前': <gensim.models.keyedvectors.Vocab at 0x259c0050b00>,
#  '一加': <gensim.models.keyedvectors.Vocab at 0x259c0050b38>,
#  '3T': <gensim.models.keyedvectors.Vocab at 0x259c0050b70>,
#  '搭载': <gensim.models.keyedvectors.Vocab at 0x259c0050ba8>,
#  '3400mAh': <gensim.models.keyedvectors.Vocab at 0x259c0050be0>,
#  '电池': <gensim.models.keyedvectors.Vocab at 0x259c0050c18>,
#  'DashCharge': <gensim.models.keyedvectors.Vocab at 0x259c0050c50>,
#  '快充': <gensim.models.keyedvectors.Vocab at 0x259c0050c88>,
#  '规格': <gensim.models.keyedvectors.Vocab at 0x259c0050cc0>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x259c0050cf8>,
#  '5V': <gensim.models.keyedvectors.Vocab at 0x259c0050d30>,
#  '4A': <gensim.models.keyedvectors.Vocab at 0x259c0050d68>,
#  '至于': <gensim.models.keyedvectors.Vocab at 0x259c0050da0>,
#  '缩水': <gensim.models.keyedvectors.Vocab at 0x259c0050dd8>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x259c0050e10>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x259c0050e48>,
#  '刘作': <gensim.models.keyedvectors.Vocab at 0x259c0050e80>,
#  '虎': <gensim.models.keyedvectors.Vocab at 0x259c0050eb8>,
#  '所说': <gensim.models.keyedvectors.Vocab at 0x259c0050ef0>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x259c0050f28>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x259c0050f60>,
#  '市面': <gensim.models.keyedvectors.Vocab at 0x259c0050f98>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x259c0050fd0>,
#  '轻薄': <gensim.models.keyedvectors.Vocab at 0x259c0053048>,
#  '大屏': <gensim.models.keyedvectors.Vocab at 0x259c0053080>,
#  '旗舰': <gensim.models.keyedvectors.Vocab at 0x259c00530b8>,
#  '设定': <gensim.models.keyedvectors.Vocab at 0x259c00530f0>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x259c0053128>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x259c0053160>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x259c0053198>,
#  '掌握': <gensim.models.keyedvectors.Vocab at 0x259c00531d0>,
#  '拥有': <gensim.models.keyedvectors.Vocab at 0x259c0053208>,
#  '5.5': <gensim.models.keyedvectors.Vocab at 0x259c0053240>,
#  '寸': <gensim.models.keyedvectors.Vocab at 0x259c0053278>,
#  '1080P': <gensim.models.keyedvectors.Vocab at 0x259c00532b0>,
#  'AMOLED': <gensim.models.keyedvectors.Vocab at 0x259c00532e8>,
#  '显示屏': <gensim.models.keyedvectors.Vocab at 0x259c0053320>,
#  '6G': <gensim.models.keyedvectors.Vocab at 0x259c0053358>,
#  '8GB': <gensim.models.keyedvectors.Vocab at 0x259c0053390>,
#  'RAM': <gensim.models.keyedvectors.Vocab at 0x259c00533c8>,
#  '64GB': <gensim.models.keyedvectors.Vocab at 0x259c0053400>,
#  '128GB': <gensim.models.keyedvectors.Vocab at 0x259c0053438>,
#  'ROM': <gensim.models.keyedvectors.Vocab at 0x259c0053470>,
#  '双': <gensim.models.keyedvectors.Vocab at 0x259c00534a8>,
#  '1600': <gensim.models.keyedvectors.Vocab at 0x259c00534e0>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x259c0053518>,
#  '摄像头': <gensim.models.keyedvectors.Vocab at 0x259c0053550>,
#  '备货': <gensim.models.keyedvectors.Vocab at 0x259c0053588>,
#  '量': <gensim.models.keyedvectors.Vocab at 0x259c00535c0>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x259c00535f8>,
#  '惊喜': <gensim.models.keyedvectors.Vocab at 0x259c0053630>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x259c0053668>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x259c00536a0>,
#  '京东': <gensim.models.keyedvectors.Vocab at 0x259c00536d8>,
#  '泄露': <gensim.models.keyedvectors.Vocab at 0x259c0053710>,
#  '售价': <gensim.models.keyedvectors.Vocab at 0x259c0053748>,
#  'xx99': <gensim.models.keyedvectors.Vocab at 0x259c0053780>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x259c00537b8>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x259c00537f0>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x259c0053828>,
#  '2799': <gensim.models.keyedvectors.Vocab at 0x259c0053860>,
#  '2899': <gensim.models.keyedvectors.Vocab at 0x259c0053898>,
#  '2999': <gensim.models.keyedvectors.Vocab at 0x259c00538d0>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x259c0053908>,
#  '某个': <gensim.models.keyedvectors.Vocab at 0x259c0053940>,
#  '这是': <gensim.models.keyedvectors.Vocab at 0x259c0053978>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x259c00539b0>,
#  '葡萄牙': <gensim.models.keyedvectors.Vocab at 0x259c00539e8>,
#  '中部': <gensim.models.keyedvectors.Vocab at 0x259c0053a20>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x259c0053a58>,
#  '佩德罗': <gensim.models.keyedvectors.Vocab at 0x259c0053a90>,
#  '冈': <gensim.models.keyedvectors.Vocab at 0x259c0053ac8>,
#  '地区': <gensim.models.keyedvectors.Vocab at 0x259c0053b00>,
#  '拍摄': <gensim.models.keyedvectors.Vocab at 0x259c0053b38>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x259c0053b70>,
#  '森林': <gensim.models.keyedvectors.Vocab at 0x259c0053ba8>,
#  '大火': <gensim.models.keyedvectors.Vocab at 0x259c0053be0>,
#  '烧毁': <gensim.models.keyedvectors.Vocab at 0x259c0053c18>,
#  '汽车': <gensim.models.keyedvectors.Vocab at 0x259c0053c50>,
#  '新华社': <gensim.models.keyedvectors.Vocab at 0x259c0053c88>,
#  '记者': <gensim.models.keyedvectors.Vocab at 0x259c0053cc0>,
#  '张立': <gensim.models.keyedvectors.Vocab at 0x259c0053cf8>,
#  '云摄': <gensim.models.keyedvectors.Vocab at 0x259c0053d30>,
#  '原': <gensim.models.keyedvectors.Vocab at 0x259c0053d68>,
#  '标题': <gensim.models.keyedvectors.Vocab at 0x259c0053da0>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x259c0053dd8>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x259c0053e10>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x259c0053e48>,
#  '女子': <gensim.models.keyedvectors.Vocab at 0x259c0053e80>,
#  '跑': <gensim.models.keyedvectors.Vocab at 0x259c0053eb8>,
#  '深圳': <gensim.models.keyedvectors.Vocab at 0x259c0053ef0>,
#  '约会': <gensim.models.keyedvectors.Vocab at 0x259c0053f28>,
#  '网友': <gensim.models.keyedvectors.Vocab at 0x259c0053f60>,
#  '拒': <gensim.models.keyedvectors.Vocab at 0x259c0053f98>,
#  '暴雨': <gensim.models.keyedvectors.Vocab at 0x259c0053fd0>,
#  '裸身': <gensim.models.keyedvectors.Vocab at 0x259c0057048>,
#  '奔走': <gensim.models.keyedvectors.Vocab at 0x259c0057080>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x259c00570b8>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x259c00570f0>,
#  '交警': <gensim.models.keyedvectors.Vocab at 0x259c0057128>,
#  '微博称': <gensim.models.keyedvectors.Vocab at 0x259c0057160>,
#  '昨日': <gensim.models.keyedvectors.Vocab at 0x259c0057198>,
#  '清晨': <gensim.models.keyedvectors.Vocab at 0x259c00571d0>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x259c0057208>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x259c0057240>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x259c0057278>,
#  '赤裸': <gensim.models.keyedvectors.Vocab at 0x259c00572b0>,
#  '上身': <gensim.models.keyedvectors.Vocab at 0x259c00572e8>,
#  '行走': <gensim.models.keyedvectors.Vocab at 0x259c0057320>,
#  '南坪': <gensim.models.keyedvectors.Vocab at 0x259c0057358>,
#  '快速': <gensim.models.keyedvectors.Vocab at 0x259c0057390>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x259c00573c8>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x259c0057400>,
#  '轻生': <gensim.models.keyedvectors.Vocab at 0x259c0057438>,
#  '年头': <gensim.models.keyedvectors.Vocab at 0x259c0057470>,
#  '一辅警': <gensim.models.keyedvectors.Vocab at 0x259c00574a8>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x259c00574e0>,
#  '赶紧': <gensim.models.keyedvectors.Vocab at 0x259c0057518>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x259c0057550>,
#  '披上': <gensim.models.keyedvectors.Vocab at 0x259c0057588>,
#  '黄衣': <gensim.models.keyedvectors.Vocab at 0x259c00575c0>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x259c00575f8>,
#  '一路': <gensim.models.keyedvectors.Vocab at 0x259c0057630>,
#  '劝说': <gensim.models.keyedvectors.Vocab at 0x259c0057668>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x259c00576a0>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x259c00576d8>,
#  '事发': <gensim.models.keyedvectors.Vocab at 0x259c0057710>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x259c0057748>,
#  '到底': <gensim.models.keyedvectors.Vocab at 0x259c0057780>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x259c00577b8>,
#  '发生': <gensim.models.keyedvectors.Vocab at 0x259c00577f0>,
#  '些': <gensim.models.keyedvectors.Vocab at 0x259c0057828>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x259c0057860>,
#  '呢': <gensim.models.keyedvectors.Vocab at 0x259c0057898>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x259c00578d0>,
#  '南': <gensim.models.keyedvectors.Vocab at 0x259c0057908>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x259c0057940>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x259c0057978>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x259c00579b0>,
#  '还原': <gensim.models.keyedvectors.Vocab at 0x259c00579e8>,
#  '现场': <gensim.models.keyedvectors.Vocab at 0x259c0057a20>,
#  '龙岗': <gensim.models.keyedvectors.Vocab at 0x259c0057a58>,
#  '大队': <gensim.models.keyedvectors.Vocab at 0x259c0057a90>,
#  '坂田': <gensim.models.keyedvectors.Vocab at 0x259c0057ac8>,
#  '中队': <gensim.models.keyedvectors.Vocab at 0x259c0057b00>,
#  '辅警': <gensim.models.keyedvectors.Vocab at 0x259c0057b38>,
#  '刘青': <gensim.models.keyedvectors.Vocab at 0x259c0057b70>,
#  '女生': <gensim.models.keyedvectors.Vocab at 0x259c0057ba8>,
#  '一位': <gensim.models.keyedvectors.Vocab at 0x259c0057be0>,
#  '外表': <gensim.models.keyedvectors.Vocab at 0x259c0057c18>,
#  '高大': <gensim.models.keyedvectors.Vocab at 0x259c0057c50>,
#  '帅气': <gensim.models.keyedvectors.Vocab at 0x259c0057c88>,
#  '说话': <gensim.models.keyedvectors.Vocab at 0x259c0057cc0>,
#  '略带': <gensim.models.keyedvectors.Vocab at 0x259c0057cf8>,
#  '腼腆': <gensim.models.keyedvectors.Vocab at 0x259c0057d30>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x259c0057d68>,
#  '青年': <gensim.models.keyedvectors.Vocab at 0x259c0057da0>,
#  '介绍': <gensim.models.keyedvectors.Vocab at 0x259c0057dd8>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x259c0057e10>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x259c0057e48>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x259c0057e80>,
#  '36': <gensim.models.keyedvectors.Vocab at 0x259c0057eb8>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x259c0057ef0>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x259c0057f28>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x259c0057f60>,
#  '环城': <gensim.models.keyedvectors.Vocab at 0x259c0057f98>,
#  '南路': <gensim.models.keyedvectors.Vocab at 0x259c0057fd0>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x259c0059048>,
#  '值勤': <gensim.models.keyedvectors.Vocab at 0x259c0059080>,
#  '接到': <gensim.models.keyedvectors.Vocab at 0x259c00590b8>,
#  '机动车': <gensim.models.keyedvectors.Vocab at 0x259c00590f0>,
#  '危险': <gensim.models.keyedvectors.Vocab at 0x259c0059128>,
#  '警情': <gensim.models.keyedvectors.Vocab at 0x259c0059160>,
#  '随后': <gensim.models.keyedvectors.Vocab at 0x259c0059198>,
#  '骑着': <gensim.models.keyedvectors.Vocab at 0x259c00591d0>,
#  '铁骑': <gensim.models.keyedvectors.Vocab at 0x259c0059208>,
#  '沿路': <gensim.models.keyedvectors.Vocab at 0x259c0059240>,
#  '寻找': <gensim.models.keyedvectors.Vocab at 0x259c0059278>,
#  '大概': <gensim.models.keyedvectors.Vocab at 0x259c00592b0>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x259c00592e8>,
#  '十多分钟': <gensim.models.keyedvectors.Vocab at 0x259c0059320>,
#  '大道': <gensim.models.keyedvectors.Vocab at 0x259c0059358>,
#  '出口': <gensim.models.keyedvectors.Vocab at 0x259c0059390>,
#  '往': <gensim.models.keyedvectors.Vocab at 0x259c00593c8>,
#  '方向': <gensim.models.keyedvectors.Vocab at 0x259c0059400>,
#  '逆行': <gensim.models.keyedvectors.Vocab at 0x259c0059438>,
#  '辅道': <gensim.models.keyedvectors.Vocab at 0x259c0059470>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x259c00594a8>,
#  '身上': <gensim.models.keyedvectors.Vocab at 0x259c00594e0>,
#  '一丝不挂': <gensim.models.keyedvectors.Vocab at 0x259c0059518>,
#  '地逆': <gensim.models.keyedvectors.Vocab at 0x259c0059550>,
#  '车流': <gensim.models.keyedvectors.Vocab at 0x259c0059588>,
#  '而行': <gensim.models.keyedvectors.Vocab at 0x259c00595c0>,
#  '走时': <gensim.models.keyedvectors.Vocab at 0x259c00595f8>,
#  '停': <gensim.models.keyedvectors.Vocab at 0x259c0059630>,
#  '坐': <gensim.models.keyedvectors.Vocab at 0x259c0059668>,
#  '躺': <gensim.models.keyedvectors.Vocab at 0x259c00596a0>,
#  '险象环生': <gensim.models.keyedvectors.Vocab at 0x259c00596d8>,
#  '刘青停': <gensim.models.keyedvectors.Vocab at 0x259c0059710>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x259c0059748>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x259c0059780>,
#  '一名': <gensim.models.keyedvectors.Vocab at 0x259c00597b8>,
#  '巡防': <gensim.models.keyedvectors.Vocab at 0x259c00597f0>,
#  '员': <gensim.models.keyedvectors.Vocab at 0x259c0059828>,
#  '追': <gensim.models.keyedvectors.Vocab at 0x259c0059860>,
#  '上去': <gensim.models.keyedvectors.Vocab at 0x259c0059898>,
#  '情绪': <gensim.models.keyedvectors.Vocab at 0x259c00598d0>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x259c0059908>,
#  '低落': <gensim.models.keyedvectors.Vocab at 0x259c0059940>,
#  '话': <gensim.models.keyedvectors.Vocab at 0x259c0059978>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x259c00599b0>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x259c00599e8>,
#  '尝试': <gensim.models.keyedvectors.Vocab at 0x259c0059a20>,
#  '交流': <gensim.models.keyedvectors.Vocab at 0x259c0059a58>,
#  '离开': <gensim.models.keyedvectors.Vocab at 0x259c0059a90>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x259c0059ac8>,
#  '愿意': <gensim.models.keyedvectors.Vocab at 0x259c0059b00>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x259c0059b38>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x259c0059b70>,
#  '缓慢': <gensim.models.keyedvectors.Vocab at 0x259c0059ba8>,
#  '地往': <gensim.models.keyedvectors.Vocab at 0x259c0059be0>,
#  '快速路': <gensim.models.keyedvectors.Vocab at 0x259c0059c18>,
#  '主干道': <gensim.models.keyedvectors.Vocab at 0x259c0059c50>,
#  '走': <gensim.models.keyedvectors.Vocab at 0x259c0059c88>,
#  '此时': <gensim.models.keyedvectors.Vocab at 0x259c0059cc0>,
#  '路边': <gensim.models.keyedvectors.Vocab at 0x259c0059cf8>,
#  '聚集': <gensim.models.keyedvectors.Vocab at 0x259c0059d30>,
#  '市民': <gensim.models.keyedvectors.Vocab at 0x259c0059d68>,
#  '围观': <gensim.models.keyedvectors.Vocab at 0x259c0059da0>,
#  '为了': <gensim.models.keyedvectors.Vocab at 0x259c0059dd8>,
#  '刺激': <gensim.models.keyedvectors.Vocab at 0x259c0059e10>,
#  '一边': <gensim.models.keyedvectors.Vocab at 0x259c0059e48>,
#  '盯': <gensim.models.keyedvectors.Vocab at 0x259c0059e80>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x259c0059eb8>,
#  '驱赶': <gensim.models.keyedvectors.Vocab at 0x259c0059ef0>,
#  '群众': <gensim.models.keyedvectors.Vocab at 0x259c0059f28>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x259c0059f60>,
#  '警方': <gensim.models.keyedvectors.Vocab at 0x259c0059f98>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x259c0059fd0>,
#  '一份': <gensim.models.keyedvectors.Vocab at 0x259c005d048>,
#  '视频': <gensim.models.keyedvectors.Vocab at 0x259c005d080>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x259c005d0b8>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x259c005d0f0>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x259c005d128>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x259c005d160>,
#  '坂雪岗': <gensim.models.keyedvectors.Vocab at 0x259c005d198>,
#  '监控': <gensim.models.keyedvectors.Vocab at 0x259c005d1d0>,
#  '穿着': <gensim.models.keyedvectors.Vocab at 0x259c005d208>,
#  '白色': <gensim.models.keyedvectors.Vocab at 0x259c005d240>,
#  '内裤': <gensim.models.keyedvectors.Vocab at 0x259c005d278>,
#  '沿着': <gensim.models.keyedvectors.Vocab at 0x259c005d2b0>,
#  '当时': <gensim.models.keyedvectors.Vocab at 0x259c005d2e8>,
#  '正值': <gensim.models.keyedvectors.Vocab at 0x259c005d320>,
#  '上班': <gensim.models.keyedvectors.Vocab at 0x259c005d358>,
#  '高峰期': <gensim.models.keyedvectors.Vocab at 0x259c005d390>,
#  '十字路口': <gensim.models.keyedvectors.Vocab at 0x259c005d3c8>,
#  '排起': <gensim.models.keyedvectors.Vocab at 0x259c005d400>,
#  '长队': <gensim.models.keyedvectors.Vocab at 0x259c005d438>,
#  '当': <gensim.models.keyedvectors.Vocab at 0x259c005d470>,
#  '路上': <gensim.models.keyedvectors.Vocab at 0x259c005d4a8>,
#  '纷纷': <gensim.models.keyedvectors.Vocab at 0x259c005d4e0>,
#  '驻足': <gensim.models.keyedvectors.Vocab at 0x259c005d518>,
#  '观望': <gensim.models.keyedvectors.Vocab at 0x259c005d550>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x259c005d588>,
#  '车辆': <gensim.models.keyedvectors.Vocab at 0x259c005d5c0>,
#  '放慢': <gensim.models.keyedvectors.Vocab at 0x259c005d5f8>,
#  '速度': <gensim.models.keyedvectors.Vocab at 0x259c005d630>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x259c005d668>,
#  '停下': <gensim.models.keyedvectors.Vocab at 0x259c005d6a0>,
#  '脚步': <gensim.models.keyedvectors.Vocab at 0x259c005d6d8>,
#  '依然': <gensim.models.keyedvectors.Vocab at 0x259c005d710>,
#  '行进': <gensim.models.keyedvectors.Vocab at 0x259c005d748>,
#  '中间': <gensim.models.keyedvectors.Vocab at 0x259c005d780>,
#  '一辆': <gensim.models.keyedvectors.Vocab at 0x259c005d7b8>,
#  '货车': <gensim.models.keyedvectors.Vocab at 0x259c005d7f0>,
#  '挡住': <gensim.models.keyedvectors.Vocab at 0x259c005d828>,
#  '镜头': <gensim.models.keyedvectors.Vocab at 0x259c005d860>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x259c005d898>,
#  '再次出现': <gensim.models.keyedvectors.Vocab at 0x259c005d8d0>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x259c005d908>,
#  '穿': <gensim.models.keyedvectors.Vocab at 0x259c005d940>,
#  '全身': <gensim.models.keyedvectors.Vocab at 0x259c005d978>,
#  '裸露': <gensim.models.keyedvectors.Vocab at 0x259c005d9b0>,
#  '朝着': <gensim.models.keyedvectors.Vocab at 0x259c005d9e8>,
#  '周围': <gensim.models.keyedvectors.Vocab at 0x259c005da20>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x259c005da58>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x259c005da90>,
#  '尾随': <gensim.models.keyedvectors.Vocab at 0x259c005dac8>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x259c005db00>,
#  '上前': <gensim.models.keyedvectors.Vocab at 0x259c005db38>,
#  '劝止': <gensim.models.keyedvectors.Vocab at 0x259c005db70>,
#  '大清早': <gensim.models.keyedvectors.Vocab at 0x259c005dba8>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x259c005dbe0>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x259c005dc18>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x259c005dc50>,
#  '恐怕': <gensim.models.keyedvectors.Vocab at 0x259c005dc88>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x259c005dcc0>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x259c005dcf8>,
#  '淡定': <gensim.models.keyedvectors.Vocab at 0x259c005dd30>,
#  '面对': <gensim.models.keyedvectors.Vocab at 0x259c005dd68>,
#  '这一': <gensim.models.keyedvectors.Vocab at 0x259c005dda0>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x259c005ddd8>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x259c005de10>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x259c005de48>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x259c005de80>,
#  '心里': <gensim.models.keyedvectors.Vocab at 0x259c005deb8>,
#  '挺': <gensim.models.keyedvectors.Vocab at 0x259c005def0>,
#  '别扭': <gensim.models.keyedvectors.Vocab at 0x259c005df28>,
#  '感觉': <gensim.models.keyedvectors.Vocab at 0x259c005df60>,
#  '尴尬': <gensim.models.keyedvectors.Vocab at 0x259c005df98>,
#  '跟随': <gensim.models.keyedvectors.Vocab at 0x259c005dfd0>,
#  '作出': <gensim.models.keyedvectors.Vocab at 0x259c0061048>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x259c0061080>,
#  '意想不到': <gensim.models.keyedvectors.Vocab at 0x259c00610b8>,
#  '举动': <gensim.models.keyedvectors.Vocab at 0x259c00610f0>,
#  '突然': <gensim.models.keyedvectors.Vocab at 0x259c0061128>,
#  '靠近': <gensim.models.keyedvectors.Vocab at 0x259c0061160>,
#  '护栏': <gensim.models.keyedvectors.Vocab at 0x259c0061198>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x259c00611d0>,
#  '跳下去': <gensim.models.keyedvectors.Vocab at 0x259c0061208>,
#  '赶忙': <gensim.models.keyedvectors.Vocab at 0x259c0061240>,
#  '冲上去': <gensim.models.keyedvectors.Vocab at 0x259c0061278>,
#  '拉住': <gensim.models.keyedvectors.Vocab at 0x259c00612b0>,
#  '手': <gensim.models.keyedvectors.Vocab at 0x259c00612e8>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x259c0061320>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x259c0061358>,
#  '远离': <gensim.models.keyedvectors.Vocab at 0x259c0061390>,
#  '碍于': <gensim.models.keyedvectors.Vocab at 0x259c00613c8>,
#  '穿衣服': <gensim.models.keyedvectors.Vocab at 0x259c0061400>,
#  '刘青递': <gensim.models.keyedvectors.Vocab at 0x259c0061438>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x259c0061470>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x259c00614a8>,
#  '扔': <gensim.models.keyedvectors.Vocab at 0x259c00614e0>,
#  '排水沟': <gensim.models.keyedvectors.Vocab at 0x259c0061518>,
#  '里': <gensim.models.keyedvectors.Vocab at 0x259c0061550>,
#  '往前走': <gensim.models.keyedvectors.Vocab at 0x259c0061588>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x259c00615c0>,
#  '紧紧': <gensim.models.keyedvectors.Vocab at 0x259c00615f8>,
#  '拉': <gensim.models.keyedvectors.Vocab at 0x259c0061630>,
#  '一只': <gensim.models.keyedvectors.Vocab at 0x259c0061668>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x259c00616a0>,
#  '后面': <gensim.models.keyedvectors.Vocab at 0x259c00616d8>,
#  '一路上': <gensim.models.keyedvectors.Vocab at 0x259c0061710>,
#  '耐心': <gensim.models.keyedvectors.Vocab at 0x259c0061748>,
#  '开导': <gensim.models.keyedvectors.Vocab at 0x259c0061780>,
#  '安慰': <gensim.models.keyedvectors.Vocab at 0x259c00617b8>,
#  '听到': <gensim.models.keyedvectors.Vocab at 0x259c00617f0>,
#  '不断': <gensim.models.keyedvectors.Vocab at 0x259c0061828>,
#  '重复': <gensim.models.keyedvectors.Vocab at 0x259c0061860>,
#  '一句': <gensim.models.keyedvectors.Vocab at 0x259c0061898>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x259c00618d0>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x259c0061908>,
#  '遭遇': <gensim.models.keyedvectors.Vocab at 0x259c0061940>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x259c0061978>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x259c00619b0>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x259c00619e8>,
#  '不时': <gensim.models.keyedvectors.Vocab at 0x259c0061a20>,
#  '试图': <gensim.models.keyedvectors.Vocab at 0x259c0061a58>,
#  '挣脱': <gensim.models.keyedvectors.Vocab at 0x259c0061a90>,
#  '手要': <gensim.models.keyedvectors.Vocab at 0x259c0061ac8>,
#  '冲向': <gensim.models.keyedvectors.Vocab at 0x259c0061b00>,
#  '往下跳': <gensim.models.keyedvectors.Vocab at 0x259c0061b38>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x259c0061b70>,
#  '牵': <gensim.models.keyedvectors.Vocab at 0x259c0061ba8>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x259c0061be0>,
#  '下起': <gensim.models.keyedvectors.Vocab at 0x259c0061c18>,
#  '大暴雨': <gensim.models.keyedvectors.Vocab at 0x259c0061c50>,
#  '雨大': <gensim.models.keyedvectors.Vocab at 0x259c0061c88>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x259c0061cc0>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x259c0061cf8>,
#  '睁不开': <gensim.models.keyedvectors.Vocab at 0x259c0061d30>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x259c0061d68>,
#  '瞬间': <gensim.models.keyedvectors.Vocab at 0x259c0061da0>,
#  '雨': <gensim.models.keyedvectors.Vocab at 0x259c0061dd8>,
#  '透': <gensim.models.keyedvectors.Vocab at 0x259c0061e10>,
#  '帮助': <gensim.models.keyedvectors.Vocab at 0x259c0061e48>,
#  '冒': <gensim.models.keyedvectors.Vocab at 0x259c0061e80>,
#  '大雨': <gensim.models.keyedvectors.Vocab at 0x259c0061eb8>,
#  '四十分钟': <gensim.models.keyedvectors.Vocab at 0x259c0061ef0>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x259c0061f28>,
#  '来说': <gensim.models.keyedvectors.Vocab at 0x259c0061f60>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x259c0061f98>,
#  '回家': <gensim.models.keyedvectors.Vocab at 0x259c0061fd0>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x259c0064048>,
#  '递过来': <gensim.models.keyedvectors.Vocab at 0x259c0064080>,
#  '微博上': <gensim.models.keyedvectors.Vocab at 0x259c00640b8>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x259c00640f0>,
#  '披着': <gensim.models.keyedvectors.Vocab at 0x259c0064128>,
#  '小心翼翼': <gensim.models.keyedvectors.Vocab at 0x259c0064160>,
#  '旁边': <gensim.models.keyedvectors.Vocab at 0x259c0064198>,
#  '场景': <gensim.models.keyedvectors.Vocab at 0x259c00641d0>,
#  '南平': <gensim.models.keyedvectors.Vocab at 0x259c0064208>,
#  '下来': <gensim.models.keyedvectors.Vocab at 0x259c0064240>,
#  '带到': <gensim.models.keyedvectors.Vocab at 0x259c0064278>,
#  '派出所': <gensim.models.keyedvectors.Vocab at 0x259c00642b0>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x259c00642e8>,
#  '姑娘': <gensim.models.keyedvectors.Vocab at 0x259c0064320>,
#  '什么样': <gensim.models.keyedvectors.Vocab at 0x259c0064358>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x259c0064390>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x259c00643c8>,
#  '据': <gensim.models.keyedvectors.Vocab at 0x259c0064400>,
#  '透露': <gensim.models.keyedvectors.Vocab at 0x259c0064438>,
#  '姓': <gensim.models.keyedvectors.Vocab at 0x259c0064470>,
#  '陈': <gensim.models.keyedvectors.Vocab at 0x259c00644a8>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x259c00644e0>,
#  '湖北': <gensim.models.keyedvectors.Vocab at 0x259c0064518>,
#  '家属': <gensim.models.keyedvectors.Vocab at 0x259c0064550>,
#  '反映': <gensim.models.keyedvectors.Vocab at 0x259c0064588>,
#  '其有': <gensim.models.keyedvectors.Vocab at 0x259c00645c0>,
#  '精神病': <gensim.models.keyedvectors.Vocab at 0x259c00645f8>,
#  '史': <gensim.models.keyedvectors.Vocab at 0x259c0064630>,
#  '三天': <gensim.models.keyedvectors.Vocab at 0x259c0064668>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x259c00646a0>,
#  '陈某': <gensim.models.keyedvectors.Vocab at 0x259c00646d8>,
#  '老家': <gensim.models.keyedvectors.Vocab at 0x259c0064710>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x259c0064748>,
#  '受挫': <gensim.models.keyedvectors.Vocab at 0x259c0064780>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x259c00647b8>,
#  '异常': <gensim.models.keyedvectors.Vocab at 0x259c00647f0>,
#  '遂': <gensim.models.keyedvectors.Vocab at 0x259c0064828>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x259c0064860>,
#  '念头': <gensim.models.keyedvectors.Vocab at 0x259c0064898>,
#  '送往': <gensim.models.keyedvectors.Vocab at 0x259c00648d0>,
#  '某': <gensim.models.keyedvectors.Vocab at 0x259c0064908>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x259c0064940>,
#  '治疗': <gensim.models.keyedvectors.Vocab at 0x259c0064978>,
#  '大大': <gensim.models.keyedvectors.Vocab at 0x259c00649b0>,
#  '君': <gensim.models.keyedvectors.Vocab at 0x259c00649e8>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x259c0064a20>,
#  '早点': <gensim.models.keyedvectors.Vocab at 0x259c0064a58>,
#  '康复': <gensim.models.keyedvectors.Vocab at 0x259c0064a90>,
#  '其实': <gensim.models.keyedvectors.Vocab at 0x259c0064ac8>,
#  '真爱': <gensim.models.keyedvectors.Vocab at 0x259c0064b00>,
#  '到来': <gensim.models.keyedvectors.Vocab at 0x259c0064b38>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x259c0064b70>,
#  '年龄': <gensim.models.keyedvectors.Vocab at 0x259c0064ba8>,
#  '限制': <gensim.models.keyedvectors.Vocab at 0x259c0064be0>,
#  '你们': <gensim.models.keyedvectors.Vocab at 0x259c0064c18>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x259c0064c50>,
#  '善良': <gensim.models.keyedvectors.Vocab at 0x259c0064c88>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x259c0064cc0>,
#  '一众': <gensim.models.keyedvectors.Vocab at 0x259c0064cf8>,
#  '暖': <gensim.models.keyedvectors.Vocab at 0x259c0064d30>,
#  '男点': <gensim.models.keyedvectors.Vocab at 0x259c0064d68>,
#  'ZAN': <gensim.models.keyedvectors.Vocab at 0x259c0064da0>,
#  '弓常': <gensim.models.keyedvectors.Vocab at 0x259c0064dd8>,
#  'yan': <gensim.models.keyedvectors.Vocab at 0x259c0064e10>,
#  '桦': <gensim.models.keyedvectors.Vocab at 0x259c0064e48>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x259c0064e80>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x259c0064eb8>,
#  '哥哥': <gensim.models.keyedvectors.Vocab at 0x259c0064ef0>,
#  '女票': <gensim.models.keyedvectors.Vocab at 0x259c0064f28>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x259c0064f60>,
#  '原谅': <gensim.models.keyedvectors.Vocab at 0x259c0064f98>,
#  '一辈子': <gensim.models.keyedvectors.Vocab at 0x259c0064fd0>,
#  '浪荡': <gensim.models.keyedvectors.Vocab at 0x259c0067048>,
#  '不羁': <gensim.models.keyedvectors.Vocab at 0x259c0067080>,
#  '爱': <gensim.models.keyedvectors.Vocab at 0x259c00670b8>,
#  '萨摩耶': <gensim.models.keyedvectors.Vocab at 0x259c00670f0>,
#  '过不去': <gensim.models.keyedvectors.Vocab at 0x259c0067128>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x259c0067160>,
#  '想想': <gensim.models.keyedvectors.Vocab at 0x259c0067198>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x259c00671d0>,
#  '家人': <gensim.models.keyedvectors.Vocab at 0x259c0067208>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x259c0067240>,
#  '感谢': <gensim.models.keyedvectors.Vocab at 0x259c0067278>,
#  '蜀黍': <gensim.models.keyedvectors.Vocab at 0x259c00672b0>,
#  '火心': <gensim.models.keyedvectors.Vocab at 0x259c00672e8>,
#  '聆听': <gensim.models.keyedvectors.Vocab at 0x259c0067320>,
#  '心灵': <gensim.models.keyedvectors.Vocab at 0x259c0067358>,
#  '点赞': <gensim.models.keyedvectors.Vocab at 0x259c0067390>,
#  '中華云盾': <gensim.models.keyedvectors.Vocab at 0x259c00673c8>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x259c0067400>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x259c0067438>,
#  '需时': <gensim.models.keyedvectors.Vocab at 0x259c0067470>,
#  '申出': <gensim.models.keyedvectors.Vocab at 0x259c00674a8>,
#  '援手': <gensim.models.keyedvectors.Vocab at 0x259c00674e0>,
#  'Tomchlee': <gensim.models.keyedvectors.Vocab at 0x259c0067518>,
#  '帅': <gensim.models.keyedvectors.Vocab at 0x259c0067550>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x259c0067588>,
#  'SJ': <gensim.models.keyedvectors.Vocab at 0x259c00675c0>,
#  '李赫海': <gensim.models.keyedvectors.Vocab at 0x259c00675f8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x259c0067630>,
#  '木有': <gensim.models.keyedvectors.Vocab at 0x259c0067668>,
#  '男子': <gensim.models.keyedvectors.Vocab at 0x259c00676a0>,
#  '迷奸': <gensim.models.keyedvectors.Vocab at 0x259c00676d8>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x259c0067710>,
#  '418': <gensim.models.keyedvectors.Vocab at 0x259c0067748>,
#  '女方': <gensim.models.keyedvectors.Vocab at 0x259c0067780>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x259c00677b8>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x259c00677f0>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x259c0067828>,
#  '上午': <gensim.models.keyedvectors.Vocab at 0x259c0067860>,
#  '淮安市': <gensim.models.keyedvectors.Vocab at 0x259c0067898>,
#  '涟水县': <gensim.models.keyedvectors.Vocab at 0x259c00678d0>,
#  '公安局': <gensim.models.keyedvectors.Vocab at 0x259c0067908>,
#  '刑警大队': <gensim.models.keyedvectors.Vocab at 0x259c0067940>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x259c0067978>,
#  '奇怪': <gensim.models.keyedvectors.Vocab at 0x259c00679b0>,
#  '报警': <gensim.models.keyedvectors.Vocab at 0x259c00679e8>,
#  '电话': <gensim.models.keyedvectors.Vocab at 0x259c0067a20>,
#  '言语': <gensim.models.keyedvectors.Vocab at 0x259c0067a58>,
#  '不清': <gensim.models.keyedvectors.Vocab at 0x259c0067a90>,
#  '声称': <gensim.models.keyedvectors.Vocab at 0x259c0067ac8>,
#  '遭到': <gensim.models.keyedvectors.Vocab at 0x259c0067b00>,
#  '侵害': <gensim.models.keyedvectors.Vocab at 0x259c0067b38>,
#  '几个': <gensim.models.keyedvectors.Vocab at 0x259c0067b70>,
#  '关键词': <gensim.models.keyedvectors.Vocab at 0x259c0067ba8>,
#  '令': <gensim.models.keyedvectors.Vocab at 0x259c0067be0>,
#  '民警': <gensim.models.keyedvectors.Vocab at 0x259c0067c18>,
#  '紧张': <gensim.models.keyedvectors.Vocab at 0x259c0067c50>,
#  '起来': <gensim.models.keyedvectors.Vocab at 0x259c0067c88>,
#  '受到': <gensim.models.keyedvectors.Vocab at 0x259c0067cc0>,
#  'A股': <gensim.models.keyedvectors.Vocab at 0x259c0067cf8>,
#  '纳入': <gensim.models.keyedvectors.Vocab at 0x259c0067d30>,
#  'MSCI': <gensim.models.keyedvectors.Vocab at 0x259c0067d68>,
#  '指数': <gensim.models.keyedvectors.Vocab at 0x259c0067da0>,
#  '利好': <gensim.models.keyedvectors.Vocab at 0x259c0067dd8>,
#  '消息': <gensim.models.keyedvectors.Vocab at 0x259c0067e10>,
#  '市场': <gensim.models.keyedvectors.Vocab at 0x259c0067e48>,
#  '周三': <gensim.models.keyedvectors.Vocab at 0x259c0067e80>,
#  '再度': <gensim.models.keyedvectors.Vocab at 0x259c0067eb8>,
#  '上演': <gensim.models.keyedvectors.Vocab at 0x259c0067ef0>,
#  '龙马': <gensim.models.keyedvectors.Vocab at 0x259c0067f28>,
#  '行情': <gensim.models.keyedvectors.Vocab at 0x259c0067f60>,
#  '周四': <gensim.models.keyedvectors.Vocab at 0x259c0067f98>,
#  '金融股': <gensim.models.keyedvectors.Vocab at 0x259c0067fd0>,
#  '白马股': <gensim.models.keyedvectors.Vocab at 0x259c006c048>,
#  '表现': <gensim.models.keyedvectors.Vocab at 0x259c006c080>,
#  '喜人': <gensim.models.keyedvectors.Vocab at 0x259c006c0b8>,
#  '尾盘': <gensim.models.keyedvectors.Vocab at 0x259c006c0f0>,
#  '跳水': <gensim.models.keyedvectors.Vocab at 0x259c006c128>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x259c006c160>,
#  '仅': <gensim.models.keyedvectors.Vocab at 0x259c006c198>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x259c006c1d0>,
#  '板块': <gensim.models.keyedvectors.Vocab at 0x259c006c208>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x259c006c240>,
#  '维系': <gensim.models.keyedvectors.Vocab at 0x259c006c278>,
#  '红盘': <gensim.models.keyedvectors.Vocab at 0x259c006c2b0>,
#  '状态': <gensim.models.keyedvectors.Vocab at 0x259c006c2e8>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x259c006c320>,
#  '人士': <gensim.models.keyedvectors.Vocab at 0x259c006c358>,
#  '认为': <gensim.models.keyedvectors.Vocab at 0x259c006c390>,
#  '受益': <gensim.models.keyedvectors.Vocab at 0x259c006c3c8>,
#  '于': <gensim.models.keyedvectors.Vocab at 0x259c006c400>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x259c006c438>,
#  '估值': <gensim.models.keyedvectors.Vocab at 0x259c006c470>,
#  '重获': <gensim.models.keyedvectors.Vocab at 0x259c006c4a8>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x259c006c4e0>,
#  '青睐': <gensim.models.keyedvectors.Vocab at 0x259c006c518>,
#  '存量': <gensim.models.keyedvectors.Vocab at 0x259c006c550>,
#  '博弈': <gensim.models.keyedvectors.Vocab at 0x259c006c588>,
#  '格局': <gensim.models.keyedvectors.Vocab at 0x259c006c5c0>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x259c006c5f8>,
#  '风格': <gensim.models.keyedvectors.Vocab at 0x259c006c630>,
#  '交替': <gensim.models.keyedvectors.Vocab at 0x259c006c668>,
#  '震荡': <gensim.models.keyedvectors.Vocab at 0x259c006c6a0>,
#  '料': <gensim.models.keyedvectors.Vocab at 0x259c006c6d8>,
#  '延续': <gensim.models.keyedvectors.Vocab at 0x259c006c710>,
#  '流动性': <gensim.models.keyedvectors.Vocab at 0x259c006c748>,
#  '改善': <gensim.models.keyedvectors.Vocab at 0x259c006c780>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x259c006c7b8>,
#  '悲观': <gensim.models.keyedvectors.Vocab at 0x259c006c7f0>,
#  '预期': <gensim.models.keyedvectors.Vocab at 0x259c006c828>,
#  '修正': <gensim.models.keyedvectors.Vocab at 0x259c006c860>,
#  '有助于': <gensim.models.keyedvectors.Vocab at 0x259c006c898>,
#  '支撑': <gensim.models.keyedvectors.Vocab at 0x259c006c8d0>,
#  '继而': <gensim.models.keyedvectors.Vocab at 0x259c006c908>,
#  '大盘': <gensim.models.keyedvectors.Vocab at 0x259c006c940>,
#  '逐步': <gensim.models.keyedvectors.Vocab at 0x259c006c978>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x259c006c9b0>,
#  '九': <gensim.models.keyedvectors.Vocab at 0x259c006c9e8>,
#  '再现': <gensim.models.keyedvectors.Vocab at 0x259c006ca20>,
#  '未能': <gensim.models.keyedvectors.Vocab at 0x259c006ca58>,
#  '上行': <gensim.models.keyedvectors.Vocab at 0x259c006ca90>,
#  '态势': <gensim.models.keyedvectors.Vocab at 0x259c006cac8>,
#  '两市': <gensim.models.keyedvectors.Vocab at 0x259c006cb00>,
#  '成交': <gensim.models.keyedvectors.Vocab at 0x259c006cb38>,
#  '小幅': <gensim.models.keyedvectors.Vocab at 0x259c006cb70>,
#  '放量': <gensim.models.keyedvectors.Vocab at 0x259c006cba8>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x259c006cbe0>,
#  '中信': <gensim.models.keyedvectors.Vocab at 0x259c006cc18>,
#  '一级': <gensim.models.keyedvectors.Vocab at 0x259c006cc50>,
#  '行业': <gensim.models.keyedvectors.Vocab at 0x259c006cc88>,
#  '收盘': <gensim.models.keyedvectors.Vocab at 0x259c006ccc0>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x259c006ccf8>,
#  '非银行': <gensim.models.keyedvectors.Vocab at 0x259c006cd30>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x259c006cd68>,
#  '收红': <gensim.models.keyedvectors.Vocab at 0x259c006cda0>,
#  '分别': <gensim.models.keyedvectors.Vocab at 0x259c006cdd8>,
#  '上涨': <gensim.models.keyedvectors.Vocab at 0x259c006ce10>,
#  '1.80%': <gensim.models.keyedvectors.Vocab at 0x259c006ce48>,
#  '0.20%': <gensim.models.keyedvectors.Vocab at 0x259c006ce80>,
#  '二级': <gensim.models.keyedvectors.Vocab at 0x259c006ceb8>,
#  '来看': <gensim.models.keyedvectors.Vocab at 0x259c006cef0>,
#  '股份制': <gensim.models.keyedvectors.Vocab at 0x259c006cf28>,
#  '城商行': <gensim.models.keyedvectors.Vocab at 0x259c006cf60>,
#  '涨幅': <gensim.models.keyedvectors.Vocab at 0x259c006cf98>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x259c006cfd0>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x259c0070048>,
#  '2.22%': <gensim.models.keyedvectors.Vocab at 0x259c0070080>,
#  '国有银行': <gensim.models.keyedvectors.Vocab at 0x259c00700b8>,
#  '0.82%': <gensim.models.keyedvectors.Vocab at 0x259c00700f0>,
#  '信托': <gensim.models.keyedvectors.Vocab at 0x259c0070128>,
#  '及其': <gensim.models.keyedvectors.Vocab at 0x259c0070160>,
#  '0.64%': <gensim.models.keyedvectors.Vocab at 0x259c0070198>,
#  '保险': <gensim.models.keyedvectors.Vocab at 0x259c00701d0>,
#  '0.34%': <gensim.models.keyedvectors.Vocab at 0x259c0070208>,
#  '证券': <gensim.models.keyedvectors.Vocab at 0x259c0070240>,
#  '0.06%': <gensim.models.keyedvectors.Vocab at 0x259c0070278>,
#  '成分股': <gensim.models.keyedvectors.Vocab at 0x259c00702b0>,
#  '共有': <gensim.models.keyedvectors.Vocab at 0x259c00702e8>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x259c0070320>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x259c0070358>,
#  '招商银行': <gensim.models.keyedvectors.Vocab at 0x259c0070390>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x259c00703c8>,
#  '6.66%': <gensim.models.keyedvectors.Vocab at 0x259c0070400>,
#  '贵阳': <gensim.models.keyedvectors.Vocab at 0x259c0070438>,
#  '3.65%': <gensim.models.keyedvectors.Vocab at 0x259c0070470>,
#  '上海银行': <gensim.models.keyedvectors.Vocab at 0x259c00704a8>,
#  '华夏银行': <gensim.models.keyedvectors.Vocab at 0x259c00704e0>,
#  '浦发银行': <gensim.models.keyedvectors.Vocab at 0x259c0070518>,
#  '兴业银行': <gensim.models.keyedvectors.Vocab at 0x259c0070550>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x259c0070588>,
#  '1.50%': <gensim.models.keyedvectors.Vocab at 0x259c00705c0>,
#  '共': <gensim.models.keyedvectors.Vocab at 0x259c00705f8>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x259c0070630>,
#  '个股': <gensim.models.keyedvectors.Vocab at 0x259c0070668>,
#  '安信': <gensim.models.keyedvectors.Vocab at 0x259c00706a0>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x259c00706d8>,
#  '太保': <gensim.models.keyedvectors.Vocab at 0x259c0070710>,
#  '居前': <gensim.models.keyedvectors.Vocab at 0x259c0070748>,
#  '两名': <gensim.models.keyedvectors.Vocab at 0x259c0070780>,
#  '4.57%': <gensim.models.keyedvectors.Vocab at 0x259c00707b8>,
#  '3.04%': <gensim.models.keyedvectors.Vocab at 0x259c00707f0>,
#  '西水股份': <gensim.models.keyedvectors.Vocab at 0x259c0070828>,
#  '华安': <gensim.models.keyedvectors.Vocab at 0x259c0070860>,
#  '人寿': <gensim.models.keyedvectors.Vocab at 0x259c0070898>,
#  '新华': <gensim.models.keyedvectors.Vocab at 0x259c00708d0>,
#  '2%': <gensim.models.keyedvectors.Vocab at 0x259c0070908>,
#  '相对而言': <gensim.models.keyedvectors.Vocab at 0x259c0070940>,
#  '券商': <gensim.models.keyedvectors.Vocab at 0x259c0070978>,
#  '股多': <gensim.models.keyedvectors.Vocab at 0x259c00709b0>,
#  '下跌': <gensim.models.keyedvectors.Vocab at 0x259c00709e8>,
#  '近期': <gensim.models.keyedvectors.Vocab at 0x259c0070a20>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x259c0070a58>,
#  '消息面': <gensim.models.keyedvectors.Vocab at 0x259c0070a90>,
#  '宣布': <gensim.models.keyedvectors.Vocab at 0x259c0070ac8>,
#  '2018': <gensim.models.keyedvectors.Vocab at 0x259c0070b00>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x259c0070b38>,
#  '新兴': <gensim.models.keyedvectors.Vocab at 0x259c0070b70>,
#  '占': <gensim.models.keyedvectors.Vocab at 0x259c0070ba8>,
#  '群体': <gensim.models.keyedvectors.Vocab at 0x259c0070be0>,
#  '国金': <gensim.models.keyedvectors.Vocab at 0x259c0070c18>,
#  '李立峰': <gensim.models.keyedvectors.Vocab at 0x259c0070c50>,
#  '团队': <gensim.models.keyedvectors.Vocab at 0x259c0070c88>,
#  '指出': <gensim.models.keyedvectors.Vocab at 0x259c0070cc0>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x259c0070cf8>,
#  '包含': <gensim.models.keyedvectors.Vocab at 0x259c0070d30>,
#  '222': <gensim.models.keyedvectors.Vocab at 0x259c0070d68>,
#  '剔除': <gensim.models.keyedvectors.Vocab at 0x259c0070da0>,
#  '中等': <gensim.models.keyedvectors.Vocab at 0x259c0070dd8>,
#  '市值': <gensim.models.keyedvectors.Vocab at 0x259c0070e10>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x259c0070e48>,
#  '互联互通': <gensim.models.keyedvectors.Vocab at 0x259c0070e80>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x259c0070eb8>,
#  '股票': <gensim.models.keyedvectors.Vocab at 0x259c0070ef0>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x259c0070f28>,
#  '停牌': <gensim.models.keyedvectors.Vocab at 0x259c0070f60>,
#  '标的': <gensim.models.keyedvectors.Vocab at 0x259c0070f98>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x259c0070fd0>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x259c0072048>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x259c0072080>,
#  'H股': <gensim.models.keyedvectors.Vocab at 0x259c00720b8>,
#  'EM': <gensim.models.keyedvectors.Vocab at 0x259c00720f0>,
#  '权重': <gensim.models.keyedvectors.Vocab at 0x259c0072128>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x259c0072160>,
#  '0.5%': <gensim.models.keyedvectors.Vocab at 0x259c0072198>,
#  '上升': <gensim.models.keyedvectors.Vocab at 0x259c00721d0>,
#  '0.73%': <gensim.models.keyedvectors.Vocab at 0x259c0072208>,
#  '40.11%': <gensim.models.keyedvectors.Vocab at 0x259c0072240>,
#  '泛': <gensim.models.keyedvectors.Vocab at 0x259c0072278>,
#  '消费': <gensim.models.keyedvectors.Vocab at 0x259c00722b0>,
#  '次之': <gensim.models.keyedvectors.Vocab at 0x259c00722e8>,
#  '24.26%': <gensim.models.keyedvectors.Vocab at 0x259c0072320>,
#  '涵盖': <gensim.models.keyedvectors.Vocab at 0x259c0072358>,
#  '大部分': <gensim.models.keyedvectors.Vocab at 0x259c0072390>,
#  '权重股': <gensim.models.keyedvectors.Vocab at 0x259c00723c8>,
#  '动态': <gensim.models.keyedvectors.Vocab at 0x259c0072400>,
#  '加入': <gensim.models.keyedvectors.Vocab at 0x259c0072438>,
#  '指': <gensim.models.keyedvectors.Vocab at 0x259c0072470>,
#  '比高': <gensim.models.keyedvectors.Vocab at 0x259c00724a8>,
#  '金融公司': <gensim.models.keyedvectors.Vocab at 0x259c00724e0>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x259c0072518>,
#  '近一半': <gensim.models.keyedvectors.Vocab at 0x259c0072550>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x259c0072588>,
#  '稀释': <gensim.models.keyedvectors.Vocab at 0x259c00725c0>,
#  '尽管': <gensim.models.keyedvectors.Vocab at 0x259c00725f8>,
#  '事件': <gensim.models.keyedvectors.Vocab at 0x259c0072630>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x259c0072668>,
#  '有所': <gensim.models.keyedvectors.Vocab at 0x259c00726a0>,
#  '提振': <gensim.models.keyedvectors.Vocab at 0x259c00726d8>,
#  '中长期': <gensim.models.keyedvectors.Vocab at 0x259c0072710>,
#  '海外': <gensim.models.keyedvectors.Vocab at 0x259c0072748>,
#  '增量': <gensim.models.keyedvectors.Vocab at 0x259c0072780>,
#  '升温': <gensim.models.keyedvectors.Vocab at 0x259c00727b8>,
#  '短期内': <gensim.models.keyedvectors.Vocab at 0x259c00727f0>,
#  '尚': <gensim.models.keyedvectors.Vocab at 0x259c0072828>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x259c0072860>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x259c0072898>,
#  '放大': <gensim.models.keyedvectors.Vocab at 0x259c00728d0>,
#  '独': <gensim.models.keyedvectors.Vocab at 0x259c0072908>,
#  '乐乐': <gensim.models.keyedvectors.Vocab at 0x259c0072940>,
#  '情景': <gensim.models.keyedvectors.Vocab at 0x259c0072978>,
#  '难以': <gensim.models.keyedvectors.Vocab at 0x259c00729b0>,
#  '持续': <gensim.models.keyedvectors.Vocab at 0x259c00729e8>,
#  '难': <gensim.models.keyedvectors.Vocab at 0x259c0072a20>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x259c0072a58>,
#  '光大': <gensim.models.keyedvectors.Vocab at 0x259c0072a90>,
#  '并未': <gensim.models.keyedvectors.Vocab at 0x259c0072ac8>,
#  '引起': <gensim.models.keyedvectors.Vocab at 0x259c0072b00>,
#  '太大': <gensim.models.keyedvectors.Vocab at 0x259c0072b38>,
#  '热情': <gensim.models.keyedvectors.Vocab at 0x259c0072b70>,
#  '成交量': <gensim.models.keyedvectors.Vocab at 0x259c0072ba8>,
#  '较为': <gensim.models.keyedvectors.Vocab at 0x259c0072be0>,
#  '平淡': <gensim.models.keyedvectors.Vocab at 0x259c0072c18>,
#  '较大': <gensim.models.keyedvectors.Vocab at 0x259c0072c50>,
#  '变化': <gensim.models.keyedvectors.Vocab at 0x259c0072c88>,
#  '成长': <gensim.models.keyedvectors.Vocab at 0x259c0072cc0>,
#  '股': <gensim.models.keyedvectors.Vocab at 0x259c0072cf8>,
#  '题材股': <gensim.models.keyedvectors.Vocab at 0x259c0072d30>,
#  '全天': <gensim.models.keyedvectors.Vocab at 0x259c0072d68>,
#  '低迷': <gensim.models.keyedvectors.Vocab at 0x259c0072da0>,
#  '表明': <gensim.models.keyedvectors.Vocab at 0x259c0072dd8>,
#  '很少': <gensim.models.keyedvectors.Vocab at 0x259c0072e10>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x259c0072e48>,
#  '之间': <gensim.models.keyedvectors.Vocab at 0x259c0072e80>,
#  '腾挪': <gensim.models.keyedvectors.Vocab at 0x259c0072eb8>,
#  '跷跷板': <gensim.models.keyedvectors.Vocab at 0x259c0072ef0>,
#  '使得': <gensim.models.keyedvectors.Vocab at 0x259c0072f28>,
#  '难有': <gensim.models.keyedvectors.Vocab at 0x259c0072f60>,
#  '突破': <gensim.models.keyedvectors.Vocab at 0x259c0072f98>,
#  '中期': <gensim.models.keyedvectors.Vocab at 0x259c0072fd0>,
#  '依旧': <gensim.models.keyedvectors.Vocab at 0x259c0076048>,
#  '偏空': <gensim.models.keyedvectors.Vocab at 0x259c0076080>,
#  '维持': <gensim.models.keyedvectors.Vocab at 0x259c00760b8>,
#  '虽然': <gensim.models.keyedvectors.Vocab at 0x259c00760f0>,
#  '至今': <gensim.models.keyedvectors.Vocab at 0x259c0076128>,
#  '夏普': <gensim.models.keyedvectors.Vocab at 0x259c0076160>,
#  '智能手机': <gensim.models.keyedvectors.Vocab at 0x259c0076198>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x259c00761d0>,
#  '排得': <gensim.models.keyedvectors.Vocab at 0x259c0076208>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x259c0076240>,
#  '没落': <gensim.models.keyedvectors.Vocab at 0x259c0076278>,
#  '2013': <gensim.models.keyedvectors.Vocab at 0x259c00762b0>,
#  '退出': <gensim.models.keyedvectors.Vocab at 0x259c00762e8>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x259c0076320>,
#  '月份': <gensim.models.keyedvectors.Vocab at 0x259c0076358>,
#  '官方': <gensim.models.keyedvectors.Vocab at 0x259c0076390>,
#  '回归': <gensim.models.keyedvectors.Vocab at 0x259c00763c8>,
#  '预示': <gensim.models.keyedvectors.Vocab at 0x259c0076400>,
#  '很快': <gensim.models.keyedvectors.Vocab at 0x259c0076438>,
#  '新机': <gensim.models.keyedvectors.Vocab at 0x259c0076470>,
#  '登场': <gensim.models.keyedvectors.Vocab at 0x259c00764a8>,
#  '第一款': <gensim.models.keyedvectors.Vocab at 0x259c00764e0>,
#  '登陆': <gensim.models.keyedvectors.Vocab at 0x259c0076518>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x259c0076550>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x259c0076588>,
#  '近日': <gensim.models.keyedvectors.Vocab at 0x259c00765c0>,
#  '型号': <gensim.models.keyedvectors.Vocab at 0x259c00765f8>,
#  'FS8016': <gensim.models.keyedvectors.Vocab at 0x259c0076630>,
#  '神秘': <gensim.models.keyedvectors.Vocab at 0x259c0076668>,
#  '悄然': <gensim.models.keyedvectors.Vocab at 0x259c00766a0>,
#  'GeekBench': <gensim.models.keyedvectors.Vocab at 0x259c00766d8>,
#  '分库': <gensim.models.keyedvectors.Vocab at 0x259c0076710>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x259c0076748>,
#  '机子': <gensim.models.keyedvectors.Vocab at 0x259c0076780>,
#  '并非': <gensim.models.keyedvectors.Vocab at 0x259c00767b8>,
#  '定位': <gensim.models.keyedvectors.Vocab at 0x259c00767f0>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x259c0076828>,
#  '660': <gensim.models.keyedvectors.Vocab at 0x259c0076860>,
#  '配备': <gensim.models.keyedvectors.Vocab at 0x259c0076898>,
#  '4GB': <gensim.models.keyedvectors.Vocab at 0x259c00768d0>,
#  '内存': <gensim.models.keyedvectors.Vocab at 0x259c0076908>,
#  '最受': <gensim.models.keyedvectors.Vocab at 0x259c0076940>,
#  '瞩目': <gensim.models.keyedvectors.Vocab at 0x259c0076978>,
#  '芯片': <gensim.models.keyedvectors.Vocab at 0x259c00769b0>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x259c00769e8>,
#  '采用': <gensim.models.keyedvectors.Vocab at 0x259c0076a20>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x259c0076a58>,
#  '纳米': <gensim.models.keyedvectors.Vocab at 0x259c0076a90>,
#  '工艺': <gensim.models.keyedvectors.Vocab at 0x259c0076ac8>,
#  '八个': <gensim.models.keyedvectors.Vocab at 0x259c0076b00>,
#  'Kryo': <gensim.models.keyedvectors.Vocab at 0x259c0076b38>,
#  '260': <gensim.models.keyedvectors.Vocab at 0x259c0076b70>,
#  '设计': <gensim.models.keyedvectors.Vocab at 0x259c0076ba8>,
#  'Adreno': <gensim.models.keyedvectors.Vocab at 0x259c0076be0>,
#  '512': <gensim.models.keyedvectors.Vocab at 0x259c0076c18>,
#  'X12': <gensim.models.keyedvectors.Vocab at 0x259c0076c50>,
#  'LTE': <gensim.models.keyedvectors.Vocab at 0x259c0076c88>,
#  '调制解调器': <gensim.models.keyedvectors.Vocab at 0x259c0076cc0>,
#  '当前': <gensim.models.keyedvectors.Vocab at 0x259c0076cf8>,
#  '市面上': <gensim.models.keyedvectors.Vocab at 0x259c0076d30>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x259c0076d68>,
#  '上市': <gensim.models.keyedvectors.Vocab at 0x259c0076da0>,
#  '销售': <gensim.models.keyedvectors.Vocab at 0x259c0076dd8>,
#  'OPPO': <gensim.models.keyedvectors.Vocab at 0x259c0076e10>,
#  'R11': <gensim.models.keyedvectors.Vocab at 0x259c0076e48>,
#  '核新能': <gensim.models.keyedvectors.Vocab at 0x259c0076e80>,
#  '820': <gensim.models.keyedvectors.Vocab at 0x259c0076eb8>,
#  '强': <gensim.models.keyedvectors.Vocab at 0x259c0076ef0>,
#  '单核': <gensim.models.keyedvectors.Vocab at 0x259c0076f28>,
#  '改进': <gensim.models.keyedvectors.Vocab at 0x259c0076f60>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x259c0076f98>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x259c0076fd0>,
#  '放在': <gensim.models.keyedvectors.Vocab at 0x259c007a048>,
#  '变成': <gensim.models.keyedvectors.Vocab at 0x259c007a080>,
#  '高端': <gensim.models.keyedvectors.Vocab at 0x259c007a0b8>,
#  '机': <gensim.models.keyedvectors.Vocab at 0x259c007a0f0>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x259c007a128>,
#  '签署': <gensim.models.keyedvectors.Vocab at 0x259c007a160>,
#  '排他性': <gensim.models.keyedvectors.Vocab at 0x259c007a198>,
#  '协议': <gensim.models.keyedvectors.Vocab at 0x259c007a1d0>,
#  '独占': <gensim.models.keyedvectors.Vocab at 0x259c007a208>,
#  ...}

# %% [markdown]
# ## 现在是 mini 测试集，如果大家把维基百科+新闻语料库的所有信息全部加上，那么效果肯定会不错的

# %% [markdown]
# import re
# symbol='[^（|^）|^《|^》|^、|^“|^”|^「|^」|^：|^?|^\(|^\)|^·|^……|^；|^，|^\-|^,|^。|^:|^-|^.|^/]'
# symbol='[^(（|）|《|》|“|”|「|」|，|。|、|\-|：|·|；|?|,|.|:|"|\'|\')]'
# #print(symbol)
# def token(string):
#     return ''.join(re.findall(symbol,string))
#
# inputFile = open("./Assi2/output_zhwiki.txt",encoding='gb18030')
# a=inputFile.read()
# #print(a)
# text=token(str(a))
#
# with open('wiki_word_cut_output.txt', 'w',encoding='gb18030') as f:
#     f.write(cut(text) + '\n')

# %%
sentences_wiki = LineSentence(open('./wiki_word_cut_output.txt',encoding='gb18030'))

# %%
model_wiki = Word2Vec(sentences_wiki, min_count=1, workers=8)

# %%
model_wiki.wv['数学']
# Out:
# array([-3.0885653e+00, -1.8269283e-01, -1.5537006e+00,  6.9298333e-01,
#         1.7376687e-01,  2.6447877e-01,  3.5894725e-01, -4.1696829e-01,
#         1.0150263e+00,  7.4280970e-02,  2.2938488e-01,  2.3033876e+00,
#        -3.3072636e+00,  8.6728239e-01,  6.7922336e-01, -3.5787578e+00,
#         1.5994387e+00, -2.2107170e+00, -1.2253116e+00, -2.8080683e+00,
#        -1.6978714e+00, -2.1287398e+00,  1.8574107e+00, -9.3597986e-02,
#        -7.6136106e-01, -5.2528236e-02, -9.6218145e-01,  3.8828725e-01,
#        -3.1233129e-01, -1.2571319e+00,  3.6064255e+00,  1.4689661e+00,
#         1.3079387e+00, -1.4083418e+00, -2.2441742e+00,  3.4256154e-01,
#         5.0745302e-01,  2.4612470e+00,  4.9507859e-01,  6.9859400e-02,
#        -3.4962437e+00, -3.0468592e-01,  1.3595114e+00,  2.4996781e+00,
#        -7.1102864e-01,  4.3049073e+00, -3.6559174e+00, -8.8668323e-01,
#         2.0907116e+00,  2.1288273e+00,  2.1758530e+00,  1.5339549e+00,
#         8.4153575e-01, -5.8325183e-01, -8.7139761e-01, -2.1970997e+00,
#         4.9088174e-01, -8.6030787e-01, -3.6140497e+00, -1.2606281e+00,
#         2.1835804e-01,  1.4315074e-02, -5.0332862e-01,  7.7254283e-01,
#         1.8671453e+00,  1.4136668e+00,  3.3042853e+00, -1.4689277e+00,
#        -7.2533474e-04,  1.1435988e+00,  8.7836123e-01,  1.2929586e+00,
#        -2.1951456e+00, -1.2782739e+00, -1.0364108e+00,  3.4334924e+00,
#        -2.3941872e+00, -1.4835033e+00,  2.1838827e+00,  1.0181842e+00,
#         3.6963245e-01,  8.0263710e-01,  2.5759637e+00, -1.8908743e+00,
#        -3.6163323e+00, -1.1504521e+00,  2.4617767e+00, -2.5593877e-01,
#        -3.9812281e+00, -1.1935092e+00,  3.1526521e-01, -5.8444959e-01,
#        -1.5436347e+00, -3.5262573e-01,  7.8943515e-01, -2.2738907e+00,
#        -1.3672478e+00, -4.0534300e-01, -7.9521608e-01,  1.5500342e+00],
#       dtype=float32)

# %%
model_wiki.most_similar('数学',topn=20)
# Out:
# d:\anaconda3\envs\aicourse\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('物理', 0.8458156585693359),
#  ('计算机科学', 0.8412859439849854),
#  ('物理学', 0.8242582082748413),
#  ('统计学', 0.8203920125961304),
#  ('语言学', 0.7993844747543335),
#  ('哲学', 0.7975299954414368),
#  ('数论', 0.7832486629486084),
#  ('历史学', 0.7826335430145264),
#  ('逻辑学', 0.7826277613639832),
#  ('天文学', 0.7810382843017578),
#  ('社会学', 0.7804080843925476),
#  ('理论', 0.7763649225234985),
#  ('微积分', 0.7711677551269531),
#  ('几何学', 0.7673635482788086),
#  ('力学', 0.7666369676589966),
#  ('政治学', 0.7654010057449341),
#  ('伦理学', 0.7647632360458374),
#  ('数学分析', 0.7605448365211487),
#  ('心理学', 0.7569896578788757),
#  ('逻辑', 0.7558256387710571)]

# %% [markdown]
# ## Name Entity Recoginition

# %% [markdown]
# 区分出来什么是人名（person）， 组织机构名(organization), 地点(location)

# %% [markdown]
# ### 1. jieba

# %%
from jieba import posseg

# %% [markdown]
# posseg ==> Part of Speech Segment

# %%
text = """新华社华盛顿4月26日电 美国总统特朗普26日表示，美国将撤销在《武器贸易条约》上的签字。

特朗普当天在美国印第安纳州首府印第安纳波利斯举行的美国全国步枪协会年会上说，《武器贸易条约》是一个“严重误导的条约”，美国将撤销在该条约上的签字，联合国将很快收到美国正式拒绝该条约的通知。"""

# %%
for w in posseg.cut(text):
    print(w)
# Out:
# 新华社/nt
# 华盛顿/ns
# 4/m
# 月/m
# 26/m
# 日电/j
#  /x
# 美国/ns
# 总统/n
# 特朗普/nr
# 26/m
# 日/m
# 表示/v
# ，/x
# 美国/ns
# 将/d
# 撤销/v
# 在/p
# 《/x
# 武器/n
# 贸易/vn
# 条约/n
# 》/x
# 上/f
# 的/uj
# 签字/v
# 。/x
#
# /x
#
# /x
# 特朗普/nr
# 当天/t
# 在/p
# 美国/ns
# 印第安纳州/ns
# 首府/n
# 印第安纳波利斯/ns
# 举行/v
# 的/uj
# 美国/ns
# 全国/n
# 步枪/n
# 协会/n
# 年/m
# 会上/t
# 说/v
# ，/x
# 《/x
# 武器/n
# 贸易/vn
# 条约/n
# 》/x
# 是/v
# 一个/m
# “/x
# 严重/a
# 误导/n
# 的/uj
# 条约/n
# ”/x
# ，/x
# 美国/ns
# 将/d
# 撤销/v
# 在/p
# 该/r
# 条约/n
# 上/f
# 的/uj
# 签字/v
# ，/x
# 联合国/nt
# 将/d
# 很快/d
# 收到/v
# 美国/ns
# 正式/ad
# 拒绝/v
# 该/r
# 条约/n
# 的/uj
# 通知/v
# 。/x

# %% [markdown]
# ## 哈工大的 LTP

# %%
## https://pyltp.readthedocs.io/zh_CN/latest/api.html#id13

# %% [markdown]
# # Dependency Parsing 依存分析

# %%
from pyltp import SentenceSplitter
sents = SentenceSplitter.split('元芳你怎么看？我就趴窗口上看呗！')  # 分句
print ('\n'.join(sents))
# Out:
# 元芳你怎么看？
# 我就趴窗口上看呗！

# %%
import os
LTP_DATA_DIR = 'D://senior/aiCourse/AI_for_NLP/ltp_data_v3.4.0/'  # ltp模型目录的路径
cws_model_path = os.path.join(LTP_DATA_DIR, 'cws.model')
pos_model_path = os.path.join(LTP_DATA_DIR, 'pos.model')
ner_model_path = os.path.join(LTP_DATA_DIR, 'ner.model')
par_model_path = os.path.join(LTP_DATA_DIR, 'parser.model')
srl_model_path = os.path.join(LTP_DATA_DIR, 'pisrl_win.model')

# %%
from pyltp import Segmentor
segmentor = Segmentor()  # 初始化实例
segmentor.load(cws_model_path)  # 加载模型
words = segmentor.segment(text)  # 分词
print ('\t'.join(words))
segmentor.release()  # 释放模型
# Out:
# 新华社	华盛顿	4月	26日	电	美国	总统	特朗普	26日	表示	，	美国	将	撤销	在	《	武器	贸易	条约	》	上	的	签字	。
#
# 	特朗普	当天	在	美国	印第安纳州	首府	印第安纳波利斯	举行	的	美国	全国	步枪	协会	年会	上	说	，	《	武器	贸易	条约	》	是	一个	“	严重	误导	的	条约	”	，	美国	将	撤销	在	该	条约	上	的	签字	，	联合国	将	很快	收到	美国	正式	拒绝	该	条约	的	通知	。

# %%
from pyltp import Postagger
postagger = Postagger() # 初始化实例
postagger.load(pos_model_path)  # 加载模型

postags = postagger.postag(words)  # 词性标注

print ('\t'.join(postags))
postagger.release()  # 释放模型
# Out:
# ni	ns	nt	nt	n	ns	n	nh	nt	v	wp	ns	d	v	p	wp	n	v	n	wp	nd	u	v	wp	v	nz	nt	p	ns	ns	n	ns	v	u	ns	n	n	n	n	nd	v	wp	wp	n	v	n	wp	v	m	wp	a	v	u	n	wp	wp	ns	d	v	p	r	n	nd	u	v	wp	ni	d	d	v	ns	a	v	r	n	u	n	wp

# %%
from pyltp import NamedEntityRecognizer
recognizer = NamedEntityRecognizer() # 初始化实例
recognizer.load(ner_model_path)  # 加载模型


netags = recognizer.recognize(words, postags)  # 命名实体识别

print ('\t'.join(netags))
recognizer.release()  # 释放模型
# Out:
# S-Ni	S-Ns	O	O	O	S-Ns	O	S-Nh	O	O	O	S-Ns	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	B-Ns	E-Ns	O	S-Ns	O	O	B-Ni	I-Ni	I-Ni	E-Ni	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	O	S-Ns	O	O	O	O	O	O	O	O	O	S-Ni	O	O	O	S-Ns	O	O	O	O	O	O	O

# %%
from pyltp import Parser
parser = Parser() # 初始化实例
parser.load(par_model_path)  # 加载模型


arcs = parser.parse(words, postags)  # 句法分析

print ("\t".join("%d:%s" % (arc.head, arc.relation) for arc in arcs))
parser.release()  # 释放模型
# Out:
# 5:SBV	5:ADV	4:ATT	5:ADV	0:HED	7:ATT	8:ATT	10:SBV	10:ADV	5:COO	10:WP	14:SBV	14:ADV	10:VOB	23:ATT	19:WP	18:ATT	19:ATT	21:ATT	19:WP	15:POB	15:RAD	14:VOB	5:WP	26:ATT	39:ATT	33:ADV	33:ADV	30:ATT	31:ATT	32:ATT	28:POB	39:ATT	33:RAD	38:ATT	38:ATT	38:ATT	39:ATT	40:ATT	41:ADV	5:COO	41:WP	46:WP	45:ATT	46:ATT	48:SBV	46:WP	41:VOB	54:ATT	54:WP	52:ADV	54:ATT	52:RAD	48:VOB	54:WP	48:WP	59:SBV	59:ADV	48:COO	65:ATT	62:ATT	63:ATT	60:POB	60:RAD	59:VOB	59:WP	70:SBV	70:ADV	70:ADV	59:COO	73:SBV	73:ADV	77:ATT	75:ATT	73:VOB	73:RAD	70:VOB	5:WP

# %%
#from pyltp import SementicRoleLabeller
labeller = SementicRoleLabeller() # 初始化实例
labeller.load(srl_model_path)  # 加载模型


# arcs 使用依存句法分析的结果
roles = labeller.label(words, postags, arcs)  # 语义角色标注

# 打印结果
for role in roles:
    print (role.index, "".join(
        ["%s:(%d,%d)" % (arg.name, arg.range.start, arg.range.end) for arg in role.arguments]))
labeller.release()  # 释放模型
# Out:
# 9 TMP:(8,8)A1:(11,22)
# 13 A0:(11,11)ADV:(12,12)A1:(14,22)
# 32 TMP:(26,26)LOC:(27,31)
# 40 A1:(42,76)
# 47 A0:(42,46)A1:(48,54)
# 51 ADV:(50,50)
# 58 A0:(56,56)ADV:(57,57)A1:(59,64)
# 69 A0:(66,66)ADV:(67,67)ADV:(68,68)A1:(70,76)
# 72 A0:(70,70)ADV:(71,71)A1:(73,74)

# %%
length = len(words)
for i in range(length):
    print('{} {} {} '.format(words[i],postags[i],netags[i]))
# Out:
# 新华社 ni S-Ni
# 华盛顿 ns S-Ns
# 4月 nt O
# 26日 nt O
# 电 n O
# 美国 ns S-Ns
# 总统 n O
# 特朗普 nh S-Nh
# 26日 nt O
# 表示 v O
# ， wp O
# 美国 ns S-Ns
# 将 d O
# 撤销 v O
# 在 p O
# 《 wp O
# 武器 n O
# 贸易 v O
# 条约 n O
# 》 wp O
# 上 nd O
# 的 u O
# 签字 v O
# 。 wp O
#
#
#  v O
# 特朗普 nz O
# 当天 nt O
# 在 p O
# 美国 ns B-Ns
# 印第安纳州 ns E-Ns
# 首府 n O
# 印第安纳波利斯 ns S-Ns
# 举行 v O
# 的 u O
# 美国 ns B-Ni
# 全国 n I-Ni
# 步枪 n I-Ni
# 协会 n E-Ni
# 年会 n O
# 上 nd O
# 说 v O
# ， wp O
# 《 wp O
# 武器 n O
# 贸易 v O
# 条约 n O
# 》 wp O
# 是 v O
# 一个 m O
# “ wp O
# 严重 a O
# 误导 v O
# 的 u O
# 条约 n O
# ” wp O
# ， wp O
# 美国 ns S-Ns
# 将 d O
# 撤销 v O
# 在 p O
# 该 r O
# 条约 n O
# 上 nd O
# 的 u O
# 签字 v O
# ， wp O
# 联合国 ni S-Ni
# 将 d O
# 很快 d O
# 收到 v O
# 美国 ns S-Ns
# 正式 a O
# 拒绝 v O
# 该 r O
# 条约 n O
# 的 u O
# 通知 n O
# 。 wp O
